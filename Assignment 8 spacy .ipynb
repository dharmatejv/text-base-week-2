# %% [markdown]
# # Named Entity Recognition
#
# # DHARMATEJ VAYINENI (0937480)

# %% [markdown]
# # spacy 1

# %% [markdown]
# # Importing libraries

# %% [markdown]
# ## Import SpaCy in English

# %%
#!python -m spacy download en_core_web_lg 
import spacy
nlp = spacy.load("en_core_web_lg")

# %%
text = "My best friend chris thinks like an extrovert."
doc = nlp(text)
for token in doc:
    print(token, end=" | ")
# Out:
# My | best | friend | chris | thinks | like | an | extrovert | . |

# %% [markdown]
# ## What are the attributes that SpaCy adds?

# %%
import pandas as pd

def display_nlp(doc, include_punct=False):
    """Generate data frame for visualization of spaCy tokens."""
    rows = []
    for i, t in enumerate(doc):
        if not t.is_punct or include_punct:
            row = {'token': i,  'text': t.text, 'lemma_': t.lemma_, 
                   'is_stop': t.is_stop, 'is_alpha': t.is_alpha,
                   'pos_': t.pos_, 'dep_': t.dep_, 
                   'ent_type_': t.ent_type_, 'ent_iob_': t.ent_iob_}
            rows.append(row)
    
    df = pd.DataFrame(rows).set_index('token')
    df.index.name = None
    return df
display_nlp(doc)
# Out:
#         text     lemma_  is_stop  is_alpha   pos_   dep_ ent_type_ ent_iob_
# 0         My         my     True      True   PRON   poss                  O
# 1       best       good    False      True    ADJ   amod                  O
# 2     friend     friend    False      True   NOUN  nsubj                  O
# 3      chris      chris    False      True  PROPN  appos    PERSON        B
# 4     thinks      think    False      True   VERB   ROOT                  O
# 5       like       like    False      True    ADP   prep                  O
# 6         an         an     True      True    DET    det                  O
# 7  extrovert  extrovert    False      True   NOUN   pobj                  O

# %% [markdown]
# ## Removing Stop words using Spacy

# %%
text = "Dear venkat, we need to get a new playstation. Regards, tej"
doc = nlp(text)

non_stop = [t for t in doc if not t.is_stop and not t.is_punct]
print(non_stop)
# Out:
# [Dear, venkat, need, new, playstation, Regards, tej]

# %% [markdown]
# ## Find all nouns using Spacy

# %%
text = "My best friend chris thinks like an extrovert."
doc = nlp(text)

nouns = [t for t in doc if t.pos_ in ['NOUN', 'PROPN']]
print(nouns)
# Out:
# [friend, chris, extrovert]

# %% [markdown]
# ## Named Entity Recognition

# %%
text = "My best friend chris thinks like an extrovert."
doc = nlp(text)

for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (chris, PERSON)

# %%
text = "Emily Johnson, president of Global Enterprises, calls Los Angeles home." 
doc = nlp(text)

for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (Emily Johnson, PERSON) (Global Enterprises, ORG) (Los Angeles, GPE)

# %% [markdown]
# ## Visualize NERS

# %%
from spacy import displacy

displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Emily Johnson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , president of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Global Enterprises
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , calls
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Los Angeles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  home.</div></span>

# %% [markdown]
# ## Trying it on a real dataset

# %%
from bs4 import BeautifulSoup
import requests
import re

def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'lxml')  # Use 'lxml' parser instead of 'html5lib'
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

ny_bb = url_to_string('https://tax.thomsonreuters.com/en/tax-accounting')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 94

# %% [markdown]
# ## look at the NERS

# %%
displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tax &amp;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  accounting solutions for professionals, by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thomson Reuters
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  |
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thomson Reuters Skip
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to main content
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Legal Tax &amp; Accounting Trade &amp; Supply Risk &amp; Fraud News &amp; Media Books Developers Back Legal Business development
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# Billing management software
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Court
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  management software Legal calendaring solutions
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Practice management &amp; growth Project &amp; knowledge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  management Workflow automation software
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Corporate &amp; business organization
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#                                   Business practice &amp; procedure Legal forms                                  Legal form-building software
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Legal data &amp; document
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  management                                  Data management Data-driven insights
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Document management Document storage &amp; retrieval Drafting
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
#  software, service &amp; guidance                                  Contract services Drafting software Evidence                                  Electronic evidence Financial management                                  Outside counsel spend
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Law
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  firm marketing                                  Attracting &amp; retaining clients
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Custom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  legal marketing services
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Legal research &amp;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  guidance                                  Anywhere access to reference books Due diligence Legal research technology Trial readiness, process &amp; case guidance                                  Case management software
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Matter management
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Recommended Products                     Westlaw                      Conduct legal research efficiently and confidently using trusted content, proprietary editorial enhancements, and advanced technology.                     Practical Law                      Fast track case onboarding and practice with confidence. Tap into a team of experts who create and maintain timely, reliable, and accurate resources so you can jumpstart your work.                      HighQ                      A business management tool for legal professionals that automates workflow. Simplify project management, increase profits, and improve client satisfaction.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Insights                              Book
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  store                              All products              Questions? We are here to help
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Contact us Back Tax &amp; Accounting Audit &amp; accounting                                  Accounting &amp; financial management
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Audit workflow Disclosure Engagement compilation &amp; review Guidance &amp; standards
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Internal audit &amp; controls Quality control Data &amp; document
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  management                                  Certificate management
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Data management &amp; mining Document management Document storage &amp; organization Estate planning                                  Estate planning &amp; taxation Wealth management Financial planning &amp; analysis                                  Financial reporting Payroll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , compensation,
# <mark class="entity" style="background: #7aecec; p

# %% [markdown]
# ## Most popular NER types

# %%
from collections import Counter

labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'ORG': 72,
#          'PRODUCT': 5,
#          'PERSON': 4,
#          'LAW': 3,
#          'CARDINAL': 3,
#          'FAC': 3,
#          'WORK_OF_ART': 2,
#          'GPE': 1,
#          'DATE': 1})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(5)
# Out:
# [('Insights                              Book', 4),
#  ('AI', 3),
#  ('Checkpoint Edge', 3),
#  ('one', 2),
#  ('T.C. Burgin', 2)]

# %% [markdown]
# ## Let’s pick one sentence to analyze

# %%
article = nlp(ny_bb)
sentences = [x for x in article.sents]
print(sentences[5])
# Out:
# Simplify project management, increase profits, and improve client satisfaction.

# %% [markdown]
# ## NER tags

# %%
displacy.render(nlp(str(sentences[1])), jupyter=True, style='ent')
# Out:
# C:\Users\dharm\anaconda3\Lib\site-packages\spacy\displacy\__init__.py:213: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Recommended Products                     Westlaw                      Conduct legal research efficiently and confidently using trusted content, proprietary editorial enhancements, and advanced technology.                     </div></span>

# %% [markdown]
# ## Types of words in the sentence

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[2])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Practical', 'PROPN', 'Practical'),
#  ('Law', 'PROPN', 'Law'),
#  ('                     ', 'SPACE', '                     '),
#  ('Fast', 'PROPN', 'Fast'),
#  ('track', 'NOUN', 'track'),
#  ('case', 'NOUN', 'case'),
#  ('onboarding', 'VERB', 'onboarde'),
#  ('practice', 'VERB', 'practice'),
#  ('confidence', 'NOUN', 'confidence')]

# %% [markdown]
# ## Sentence dependency tree

# %%
displacy.render(nlp(str(sentences[2])), style='dep', jupyter = True, options = {'distance': 150})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="5db52fccd72448cf90df620abf9dd13e-0" class="displacy" width="1700" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Practical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">Law</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">                     </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">Fast</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">track</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">case</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">onboarding</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">practice</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">confidence.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5db52fccd72448cf90df620abf9dd13e-0-0" stroke-width="2px" d="M70,152.0 C70,77.0 195.0,77.0 195.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5db52fccd72448cf90df620abf9dd13e-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,154.0 L62,142.0 78,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5db52fccd72448cf90df620abf9dd13e-0-1" stroke-width="2px" d="M220,152.0 C220,2.0 500.0,2.0 500.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5db52fccd72448cf90df620abf9dd13e-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M220,154.0 L212,142.0 228,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5db52fccd72448cf90df620abf9dd13e-0-2" stroke-width="2px" d="M220,152.0 C220,77.0 345.0,77.0 345.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5db52fccd72448cf90df620abf9dd13e-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M345.0,154.0 L353.0,142.0 337.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5db52fccd72448cf90df620abf9dd13e-0-3" stroke-width="2px" d="M520,152.0 C520,77.0 645.0,77.0 645.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5db52fccd72448cf90df620abf9dd13e-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M520,154.0 L512,142.0 528,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5db52fccd72448cf90df620abf9dd13e-0-4" stroke-width="2px" d="M670,152.0 C670,77.0 795.0,77.0 795.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5db52fccd72448cf90df620abf9dd13e-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,154.0 L662,142.0 678,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5db52fccd72448cf90df620abf9dd13e-0-5" stroke-width="2px" d="M820,152.0 C820,77.0 945.0,77.0 945.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5db52fccd72448cf90df620abf9dd13e-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M820,154.0 L812,142.0 828,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5db52fccd72448cf90df620abf9dd13e-0-6" stroke-width="2px" d="M970,152.0 C970,77.0 1095.0,77.0 1095.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5db52fccd72448cf90df620abf9dd13e-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,154.0 L1103.0,142.0 1087.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5db52fccd72448cf90df620abf9dd13e-0-7" stroke-width="2px" d="M970,152.0 C970,2.0 1250.0,2.0 1250.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-5db52fccd72448cf90df620abf9dd13e-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1250.0,154.0 L1258.0,142.0 1242.0,142.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-5db52fccd72448cf90df620abf9dd13e-0-8" stroke-width="2px" d="M1270,152.0 C1270,77.0 1395.0,77.0 1395.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-

# %% [markdown]
# # spacy 2 (Dutch)

# %%
# !python -m spacy download de_core_news_lg
import spacy
# Load the German language model
nlp = spacy.load("de_core_news_lg")
# Out:
# Collecting de-core-news-lg==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_lg-3.7.0/de_core_news_lg-3.7.0-py3-none-any.whl (567.8 MB)
#      ---------------------------------------- 0.0/567.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/567.8 MB ? eta -:--:--
#      -------------------------------------- 0.0/567.8 MB 217.9 kB/s eta 0:43:27
#      -------------------------------------- 0.0/567.8 MB 281.8 kB/s eta 0:33:35
#      -------------------------------------- 0.1/567.8 MB 459.5 kB/s eta 0:20:36
#      ---------------------------------------- 0.5/567.8 MB 2.1 MB/s eta 0:04:30
#      ---------------------------------------- 2.1/567.8 MB 7.9 MB/s eta 0:01:12
#      --------------------------------------- 3.5/567.8 MB 11.1 MB/s eta 0:00:52
#      --------------------------------------- 4.9/567.8 MB 14.2 MB/s eta 0:00:40
#      --------------------------------------- 6.8/567.8 MB 16.7 MB/s eta 0:00:34
#       -------------------------------------- 8.7/567.8 MB 19.3 MB/s eta 0:00:29
#       ------------------------------------- 10.3/567.8 MB 31.2 MB/s eta 0:00:18
#       ------------------------------------- 11.4/567.8 MB 36.4 MB/s eta 0:00:16
#       ------------------------------------- 13.4/567.8 MB 36.4 MB/s eta 0:00:16
#      - ------------------------------------ 15.2/567.8 MB 40.9 MB/s eta 0:00:14
#      - ------------------------------------ 16.6/567.8 MB 36.4 MB/s eta 0:00:16
#      - ------------------------------------ 17.7/567.8 MB 36.4 MB/s eta 0:00:16
#      - ------------------------------------ 19.0/567.8 MB 34.4 MB/s eta 0:00:16
#      - ------------------------------------ 20.5/567.8 MB 34.4 MB/s eta 0:00:16
#      - ------------------------------------ 21.8/567.8 MB 36.4 MB/s eta 0:00:16
#      - ------------------------------------ 21.8/567.8 MB 36.4 MB/s eta 0:00:16
#      - ------------------------------------ 22.5/567.8 MB 28.4 MB/s eta 0:00:20
#      - ------------------------------------ 24.1/567.8 MB 28.5 MB/s eta 0:00:20
#      - ------------------------------------ 25.5/567.8 MB 28.5 MB/s eta 0:00:20
#      - ------------------------------------ 27.6/567.8 MB 28.4 MB/s eta 0:00:20
#      - ------------------------------------ 29.6/567.8 MB 29.7 MB/s eta 0:00:19
#      -- ----------------------------------- 31.5/567.8 MB 29.7 MB/s eta 0:00:19
#      -- ----------------------------------- 33.3/567.8 MB 40.9 MB/s eta 0:00:14
#      -- ----------------------------------- 34.9/567.8 MB 38.6 MB/s eta 0:00:14
#      -- ----------------------------------- 35.5/567.8 MB 38.5 MB/s eta 0:00:14
#      -- ----------------------------------- 35.6/567.8 MB 31.2 MB/s eta 0:00:18
#      -- ----------------------------------- 37.3/567.8 MB 29.7 MB/s eta 0:00:18
#      -- ----------------------------------- 37.9/567.8 MB 29.7 MB/s eta 0:00:18
#      -- ----------------------------------- 39.6/567.8 MB 28.5 MB/s eta 0:00:19
#      -- ----------------------------------- 41.7/567.8 MB 29.7 MB/s eta 0:00:18
#      -- ----------------------------------- 42.9/567.8 MB 28.5 MB/s eta 0:00:19
#      --- ---------------------------------- 45.0/567.8 MB 28.4 MB/s eta 0:00:19
#      --- ---------------------------------- 46.2/567.8 MB 34.4 MB/s eta 0:00:16
#      --- ---------------------------------- 47.3/567.8 MB 31.2 MB/s eta 0:00:17
#      --- ---------------------------------- 49.1/567.8 MB 34.4 MB/s eta 0:00:16
#      --- ---------------------------------- 50.3/567.8 MB 32.8 MB/s eta 0:00:16
#      --- ---------------------------------- 52.7/567.8 MB 34.4 MB/s eta 0:00:15
#      --- ---------------------------------- 54.1/567.8 MB 32.7 MB/s eta 0:00:16
#      --- ---------------------------------- 56.4/567.8 MB 36.4 MB/s eta 0:00:15
#      --- ---------------------------------- 57.4/567.8 MB 34.4 MB/s eta 0:00:15
#      --- ---------------------------------- 59.2/567.8 MB 36.3 MB/s eta 0:00:15
#      ---- --------------------------------- 61.2/567.8 MB 38.6 MB/s eta 0:00:14
#      ---- --------------------------------- 63.2/567.8 MB 36.4 MB/s eta 0:00:14
#      ---- --------------------------------- 64.1/567.8 MB 36.4 MB/s eta 0:00:14
#      ---- --------------------------------- 64.7/567.8 MB 36.4 MB/s eta 0:00:14
#      ---- --------------------------------- 65.6/567.8 MB 31.2 MB/s eta 0:00:17
#      ---- --------------------------------- 67.2/567.8 MB 31.2 MB/s eta 0:00:17
#      ---- --------------------------------- 69.1/567.8 MB 31.2 MB/s eta 0:00:16
#      ---- --------------------------------- 70.6/567.8 MB 31.2 MB/s eta 0:00:16
#      ---- --------------------------------- 71.7/567.8 MB 29.7 MB/s eta 0:00:17
#      ---- --------------------------------- 71.9/567.8 MB 27.3 MB/s eta 0:00:19
#      ---- --------------------------------- 73.0/567.8 MB 25.2 MB/s eta 0:00:20
#      ---- --------------------------------- 74.1/567.8 MB 27.3 MB/s eta 0:00:19
#      ----- -------------------------------- 75.1/567.8 MB 28.5 MB/s eta 0:00:18
#      ----- -------------------------------- 76.4/567.8 MB 27.3 MB/s eta 0:00:19
#      ----- -------------------------------- 76.5/567.8 MB 27.3 MB/s eta 0:00:19
#      ----- -------------------------------- 77.8/567.8 MB 24.2 MB/s eta 0:00:21
#      ----- -------------------------------- 79.1/567.8 MB 23.4 MB/s eta 0:00:21
#      ----- -------------------------------- 79.6/567.8 MB 22.6 MB/s eta 0:00:22
#      ----- -------------------------------- 81.1/567.8 MB 22.6 MB/s eta 0:00:22
#      ----- -------------------------------- 82.6/567.8 MB 25.2 MB/s eta 0:00:20
#      ----- -------------------------------- 84.1/567.8 MB 24.3 MB/s eta 0:00:20
#      ----- -------------------------------- 85.2/567.8 MB 25.2 MB/s eta 0:00:20
#      ----- -------------------------------- 86.4/567.8 MB 26.2 MB/s eta 0:00:19
#      ----- -------------------------------- 88.4/567.8 MB 29.7 MB/s eta 0:00:17
#      ------ ------------------------------- 89.8/567.8 MB 34.4 MB/s eta 0:00:14
#      ------ ------------------------------- 90.8/567.8 MB 29.7 MB/s eta 0:00:17
#      ------ ------------------------------- 91.7/567.8 MB 29.7 MB/s eta 0:00:17
#      ------ ------------------------------- 93.0/567.8 MB 29.7 MB/s eta 0:00:16
#      ------ ------------------------------- 94.2/567.8 MB 28.4 MB/s eta 0:00:17
#      ------ ------------------------------- 95.7/567.8 MB 31.2 MB/s eta 0:00:16
#      ------ ------------------------------- 96.4/567.8 MB 29.8 MB/s eta 0:00:16
#      ------ ------------------------------- 98.3/567.8 MB 28.4 MB/s eta 0:00:17
#      ------ ------------------------------- 99.0/567.8 MB 28.5 MB/s eta 0:00:17
#      ------ ------------------------------- 99.9/567.8 MB 25.1 MB/s eta 0:00:19
#      ------ ------------------------------ 101.7/567.8 MB 28.5 MB/s eta 0:00:17
#      ------ ------------------------------ 103.8/567.8 MB 29.7 MB/s eta 0:00:16
#      ------ ------------------------------ 105.6/567.8 MB 31.2 MB/s eta 0:00:15
#      ------- ----------------------------- 107.5/567.8 MB 32.8 MB/s eta 0:00:15
#      ------- ----------------------------- 108.0/567.8 MB 29.7 MB/s eta 0:00:16
#      ------- ----------------------------- 109.1/567.8 MB 28.4 MB/s eta 0:00:17
#      ------- ----------------------------- 110.6/567.8 MB 32.7 MB/s eta 0:00:14
#      ------- ----------------------------- 111.6/567.8 MB 29.7 MB/s eta 0:00:16
#      ------- ----------------------------- 112.9/567.8 MB 29.8 MB/s eta 0:00:16
#      ------- ----------------------------- 114.4/567.8 MB 28.5 MB/s eta 0:00:16
#      ------- ----------------------------- 116.5/567.8 MB 29.7 MB/s eta 0:00:16
#      ------- ----------------------------- 117.5/567.8 MB 27.3 MB/s eta 0:00:17
#      ------- ----------------------------- 118.7/567.8 MB 29.8 MB/s eta 0:00:16
#      ------- ----------------------------- 119.8/567.8 MB 29.7 MB/s eta 0:00:16
#      ------- ----------------------------- 121.8/567.8 MB 32.7 MB/s eta 0:00:14
#      -------- ---------------------------- 124.3/567.8 MB 36.3 MB/s eta 0:00:13
#      -------- ---------------------------- 126.4/567.8 MB 36.4 MB/s eta 0:00:13
#      -------- ---------------------------- 127.4/567.8 MB 34.4 MB/s eta 0:00:13
#      -------- ---------------------------- 129.3/567.8 MB 40.9 MB/s eta 0:00:11
#      -------- ---------------------------- 131.5/567.8 MB 43.7 MB/s eta 0:00:10
#      -------- ---------------------------- 133.1/567.8 MB 40.9 MB/s eta 0:00:11
#      -------- ---------------------------- 135.4/567.8 MB 40.9 MB/s eta 0:00:11
#      -------- ---------------------------- 137.3/567.8 MB 43.7 MB/s eta 0:00:10
#      --------- --------------------------- 139.7/567.8 MB 43.7 MB/s eta 0:00:10
#      --------- --------------------------- 141.3/567.8 MB 40.9 MB/s eta 0:00:11
#      --------- --------------------------- 143.4/567.8 MB 43.5 MB/s eta 0:00:10
#      --------- --------------------------- 145.3/567.8 MB 43.5 MB/s eta 0:00:10
#      --------- --------------------------- 145.9/567.8 MB 36.4 MB/s eta 0:00:12
#      --------- --------------------------- 147.6/567.8 MB 36.4 MB/s eta 0:00:12
#      --------- --------------------------- 148.2/567.8 MB 36.4 MB/s eta 0:00:12
#      --------- --------------------------- 149.4/567.8 MB 29.7 MB/s eta 0:00:15
#      --------- --------------------------- 149.8/567.8 MB 28.5 MB/s eta 0:00:15
#      --------- --------------------------- 151.4/567.8 MB 27.3 MB/s eta 0:00:16
#      --------- --------------------------- 153.3/567.8 MB 27.3 MB/s eta 0:00:16
#      ---------- -------------------------- 154.4/567.8 MB 25.1 MB/s eta 0:00:17
#      ---------- -------------------------- 156.7/567.8 MB 28.5 MB/s eta 0:00:15
#      ---------- -------------------------- 158.6/567.8 MB 32.8 MB/s eta 0:00:13
#      ---------- -------------------------- 161.0/567.8 MB 40.9 MB/s eta 0:00:10
#      ---------- -------------------------- 163.8/567.8 MB 43.7 MB/s eta 0:00:10
#      ---------- -------------------------- 166.1/567.8 MB 50.4 MB/s eta 0:00:08
#      ---------- -------------------------- 166.9/567.8 MB 43.5 MB/s eta 0:00:10
#      ----------- ------------------------- 169.2/567.8 MB 46.7 MB/s eta 0:00:09
#      ----------- ------------------------- 171.3/567.8 MB 43.5 MB/s eta 0:00:10
#      ----------- ------------------------- 173.4/567.8 MB 43.7 MB/s eta 0:00:10
#      ----------- ------------------------- 175.5/567.8 MB 40.9 MB/s eta 0:00:10
#      ----------- ------------------------- 177.7/567.8 MB 46.7 MB/s eta 0:00:09
#      ----------- ------------------------- 180.2/567.8 MB 46.7 MB/s eta 0:00:09
#      ----------- ------------------------- 181.1/567.8 MB 43.7 MB/s eta 0:00:09
#      ----------- ------------------------- 182.8/567.8 MB 40.9 MB/s eta 0:00:10
#      ------------ ------------------------ 185.2/567.8 MB 40.9 MB/s eta 0:00:10
#      ------------ ------------------------ 187.7/567.8 MB 40.9 MB/s eta 0:00:10
#      ------------ ------------------------ 190.3/567.8 MB 40.9 MB/s eta 0:00:10
#      ------------ ------------------------ 191.7/567.8 MB 50.4 MB/s eta 0:00:08
#      ------------ ------------------------ 193.9/567.8 MB 50.4 MB/s eta 0:00:08
#      ------------ ------------------------ 196.2/567.8 MB 50.4 MB/s eta 0:00:08
#      ------------ ------------------------ 197.9/567.8 MB 50.4 MB/s eta 0:00:08
#      ------------- ----------------------- 200.1/567.8 MB 46.7 MB/s eta 0:00:08
#      ------------- ----------------------- 202.0/567.8 MB 50.4 MB/s eta 0:00:08
#      ------------- ----------------------- 204.0/567.8 MB 46.7 MB/s eta 0:00:08
#      ------------- ----------------------- 204.9/567.8 MB 40.9 MB/s eta 0:00:09
#      ------------- ----------------------- 206.9/567.8 MB 38.6 MB/s eta 0:00:10
#      ------------- ----------------------- 208.0/567.8 MB 36.3 MB/s eta 0:00:10
#      ------------- ----------------------- 208.2/567.8 MB 34.4 MB/s eta 0:00:11
#      ------------- ----------------------- 208.7/567.8 MB 28.5 MB/s eta 0:00:13
#      ------------- ----------------------- 209.7/567.8 MB 27.3 MB/s eta 0:00:14
#      ------------- ----------------------- 211.1/567.8 MB 26.2 MB/s eta 0:00:14
#      ------------- ----------------------- 213.7/567.8 MB 27.3 MB/s eta 0:00:13
#      -------------- ---------------------- 215.5/567.8 MB 28.4 MB/s eta 0:00:13
#      -------------- ---------------------- 217.2/567.8 MB 28.4 MB/s eta 0:00:13
#      -------------- ---------------------- 219.5/567.8 MB 40.9 MB/s eta 0:00:09
#      -------------- ---------------------- 221.4/567.8 MB 46.7 MB/s eta 0:00:08
#      -------------- ---------------------- 223.1/567.8 MB 40.9 MB/s eta 0:00:09
#      -------------- ---------------------- 224.8/567.8 MB 40.9 MB/s eta 0:00:09
#      -------------- ---------------------- 226.4/567.8 MB 38.5 MB/s eta 0:00:09
#      -------------- ---------------------- 228.6/567.8 MB 38.5 MB/s eta 0:00:09
#      -------------- ---------------------- 229.6/567.8 MB 38.6 MB/s eta 0:00:09
#      -------------- ---------------------- 230.2/567.8 MB 32.8 MB/s eta 0:00:11
#      --------------- --------------------- 232.8/567.8 MB 34.4 MB/s eta 0:00:10
#      --------------- --------------------- 235.1/567.8 MB 38.5 MB/s eta 0:00:09
#      --------------- --------------------- 236.8/567.8 MB 40.9 MB/s eta 0:00:09
#      --------------- --------------------- 237.6/567.8 MB 36.3 MB/s eta 0:00:10
#      --------------- --------------------- 240.0/567.8 MB 43.7 MB/s eta 0:00:08
#      --------------- --------------------- 240.9/567.8 MB 36.4 MB/s eta 0:00:09
#      --------------- --------------------- 242.2/567.8 MB 36.4 MB/s eta 0:00:09
#      --------------- --------------------- 244.6/567.8 MB 34.4 MB/s eta 0:00:10
#      ---------------- -------------------- 246.9/567.8 MB 34.4 MB/s eta 0:00:10
#      ---------------- -------------------- 249.2/567.8 MB 40.9 MB/s eta 0:00:08
#      ---------------- -------------------- 251.7/567.8 MB 50.4 MB/s eta 0:00:07
#      ---------------- -------------------- 253.5/567.8 MB 46.7 MB/s eta 0:00:07
#      ---------------- -------------------- 255.6/567.8 MB 46.7 MB/s eta 0:00:07
#      ---------------- -------------------- 257.9/567.8 MB 46.7 MB/s eta 0:00:07
#      ---------------- -------------------- 260.0/567.8 MB 46.7 MB/s eta 0:00:07
#      ----------------- ------------------- 262.1/567.8 MB 43.5 MB/s eta 0:00:08
#      ----------------- ------------------- 262.4/567.8 MB 43.5 MB/s eta 0:00:08
#      ----------------- ------------------- 264.3/567.8 MB 38.6 MB/s eta 0:00:08
#      ----------------- ------------------- 266.4/567.8 MB 36.4 MB/s eta 0:00:09
#      ----------------- ------------------- 268.6/567.8 MB 36.4 MB/s eta 0:00:09
#      ----------------- ------------------- 270.5/567.8 MB 38.6 MB/s eta 0:00:08
#      ----------------- ------------------- 272.8/567.8 MB 50.4 MB/s eta 0:00:06
#      ----------------- ------------------- 274.8/567.8 MB 46.7 MB/s eta 0:00:07
#      ------------------ ------------------ 277.5/567.8 MB 50.4 MB/s eta 0:00:06
#      ------------------ ------------------ 278.5/567.8 MB 46.9 MB/s eta 0:00:07
#      ------------------ ------------------ 279.7/567.8 MB 40.9 MB/s eta 0:00:08
#      ------------------ ------------------ 281.3/567.8 MB 38.5 MB/s eta 0:00:08
#      ------------------ ------------------ 283.0/567.8 MB 34.4 MB/s eta 0:00:09
#      ------------------ ------------------ 285.1/567.8 MB 36.4 MB/s eta 0:00:08
#      ------------------ ------------------ 286.2/567.8 MB 32.8 MB/s eta 0:00:09
#      ------------------ ------------------ 288.0/567.8 MB 32.8 MB/s eta 0:00:09
#      ------------------ ------------------ 289.5/567.8 MB 34.4 MB/s eta 0:00:09
#      ------------------ ------------------ 291.2/567.8 MB 34.4 MB/s eta 0:00:09
#      ------------------- ----------------- 293.5/567.8 MB 36.4 MB/s eta 0:00:08
#      ------------------- ----------------- 295.1/567.8 MB 36.3 MB/s eta 0:00:08
#      ------------------- ----------------- 296.6/567.8 MB 38.5 MB/s eta 0:00:08
#      ------------------- ----------------- 298.5/567.8 MB 40.9 MB/s eta 0:00:07
#      ------------------- ----------------- 300.5/567.8 MB 40.9 MB/s eta 0:00:07
#      ------------------- ----------------- 302.5/567.8 MB 38.6 MB/s eta 0:00:07
#      ------------------- ----------------- 304.4/567.8 MB 38.5 MB/s eta 0:00:07
#      ------------------- ----------------- 306.1/567.8 MB 40.9 MB/s eta 0:00:07
#      ------------------- ----------------- 306.1/567.8 MB 40.9 MB/s eta 0:00:07
#      ------------------- ----------------- 306.1/567.8 MB 40.9 MB/s eta 0:00:07
#      -------------------- ---------------- 307.8/567.8 MB 28.4 MB/s eta 0:00:10
#      -------------------- ---------------- 308.9/567.8 MB 28.5 MB/s eta 0:00:10
#      -------------------- ---------------- 311.4/567.8 MB 28.5 MB/s eta 0:00:09
#      -------------------- ---------------- 313.6/567.8 MB 28.5 MB/s eta 0:00:09
#      -------------------- ---------------- 315.7/567.8 MB 29.7 MB/s eta 0:00:09
#      -------------------- ---------------- 318.2/567.8 MB 50.4 MB/s eta 0:00:05
#      -------------------- ---------------- 320.2/567.8 MB 50.4 MB/s eta 0:00:05
#      -------------------- ---------------- 322.2/567.8 MB 46.7 MB/s eta 0:00:06
#      --------------------- --------------- 324.8/567.8 MB 46.7 MB/s eta 0:00:06
#      --------------------- --------------- 327.5/567.8 MB 50.4 MB/s eta 0:00:05
#      --------------------- --------------- 329.4/567.8 MB 50.4 MB/s eta 0:00:05
#      --------------------- --------------- 332.4/567.8 MB 50.4 MB/s eta 0:00:05
#      --------------------- --------------- 333.9/567.8 MB 46.7 MB/s eta 0:00:06
#      --------------------- --------------- 336.3/567.8 MB 50.4 MB/s eta 0:00:05
#      ---------------------- -------------- 338.2/567.8 MB 46.7 MB/s eta 0:00:05
#      ---------------------- -------------- 339.7/567.8 MB 46.7 MB/s eta 0:00:05
#      ---------------------- -------------- 341.8/567.8 MB 43.5 MB/s eta 0:00:06
#      ---------------------- -------------- 343.7/567.8 MB 40.9 MB/s eta 0:00:06
#      ---------------------- -------------- 346.0/567.8 MB 43.7 MB/s eta 0:00:06
#      ---------------------- -------------- 348.2/567.8 MB 40.9 MB/s eta 0:00:06
#      ---------------------- -------------- 350.2/567.8 MB 46.7 MB/s eta 0:00:05
#      ---------------------- -------------- 352.3/567.8 MB 46.7 MB/s eta 0:00:05
#      ----------------------- ------------- 353.4/567.8 MB 40.9 MB/s eta 0:00:06
#      ----------------------- ------------- 355.6/567.8 MB 43.5 MB/s eta 0:00:05
#      ----------------------- ------------- 357.5/567.8 MB 43.7 MB/s eta 0:00:05
#      ----------------------- ------------- 359.7/567.8 MB 40.9 MB/s eta 0:00:06
#      ----------------------- ------------- 362.1/567.8 MB 40.9 MB/s eta 0:00:06
#      ----------------------- ------------- 363.9/567.8 MB 50.1 MB/s eta 0:00:05
#      ----------------------- ------------- 366.6/567.8 MB 46.7 MB/s eta 0:00:05
#      ------------------------ ------------ 369.1/567.8 MB 50.4 MB/s eta 0:00:04
#      ------------------------ ------------ 371.8/567.8 MB 50.4 MB/s eta 0:00:04
#      ------------------------ ------------ 374.2/567.8 MB 54.4 MB/s eta 0:00:04
#      ------------------------ ------------ 375.9/567.8 MB 50.1 MB/s eta 0:00:04
#      ------------------------ ------------ 377.6/567.8 MB 46.9 MB/s eta 0:00:05
#      ------------------------ ------------ 380.0/567.8 MB 46.9 MB/s eta 0:00:05
#      ------------------------ ------------ 381.8/567.8 MB 43.7 MB/s eta 0:00:05
#      ------------------------ ------------ 383.6/567.8 MB 40.9 MB/s eta 0:00:05
#      ------------------------- ----------- 385.4/567.8 MB 38.5 MB/s eta 0:00:05
#      ------------------------- ----------- 387.5/567.8 MB 46.7 MB/s eta 0:00:04
#      ------------------------- ----------- 390.0/567.8 MB 43.5 MB/s eta 0:00:05
#      ------------------------- ----------- 392.4/567.8 MB 46.7 MB/s eta 0:00:04
#      ------------------------- ----------- 395.1/567.8 MB 50.4 MB/s eta 0:00:04
#      ------------------------- ----------- 395.8/567.8 MB 50.4 MB/s eta 0:00:04
#      ------------------------- ----------- 397.7/567.8 MB 40.9 MB/s eta 0:00:05
#      -------------------------- ---------- 400.6/567.8 MB 43.7 MB/s eta 0:00:04
#      -------------------------- ---------- 402.7/567.8 MB 43.7 MB/s eta 0:00:04
#      -------------------------- ---------- 405.6/567.8 MB 40.9 MB/s eta 0:00:04
#      -------------------------- ---------- 408.1/567.8 MB 50.4 MB/s eta 0:00:04
#      -------------------------- ---------- 411.1/567.8 MB 54.7 MB/s eta 0:00:03
#      -------------------------- ---------- 412.8/567.8 MB 50.4 MB/s eta 0:00:04
#      --------------------------- --------- 415.5/567.8 MB 50.4 MB/s eta 0:00:04
#      --------------------------- --------- 417.3/567.8 MB 50.4 MB/s eta 0:00:03
#      --------------------------- --------- 420.1/567.8 MB 50.4 MB/s eta 0:00:03
#      --------------------------- --------- 421.4/567.8 MB 43.5 MB/s eta 0:00:04
#      --------------------------- --------- 424.2/567.8 MB 46.9 MB/s eta 0:00:04
#      --------------------------- --------- 426.5/567.8 MB 46.9 MB/s eta 0:00:04
#      --------------------------- --------- 427.9/567.8 MB 46.7 MB/s eta 0:00:03
#      ---------------------------- -------- 430.2/567.8 MB 46.9 MB/s eta 0:00:03
#      ---------------------------- -------- 432.8/567.8 MB 54.4 MB/s eta 0:00:03
#      ---------------------------- -------- 433.8/567.8 MB 46.7 MB/s eta 0:00:03
#      ---------------------------- -------- 436.0/567.8 MB 46.9 MB/s eta 0:00:03
#      ---------------------------- -------- 438.4/567.8 MB 54.4 MB/s eta 0:00:03
#      ---------------------------- -------- 440.7/567.8 MB 50.1 MB/s eta 0:00:03
#      ---------------------------- -------- 443.1/567.8 MB 50.4 MB/s eta 0:00:03
#      ----------------------------- ------- 445.2/567.8 MB 54.7 MB/s eta 0:00:03
#      ----------------------------- ------- 445.3/567.8 MB 43.7 MB/s eta 0:00:03
#      ----------------------------- ------- 447.3/567.8 MB 40.9 MB/s eta 0:00:03
#      ----------------------------- ------- 450.4/567.8 MB 40.9 MB/s eta 0:00:03
#      ----------------------------- ------- 453.2/567.8 MB 43.5 MB/s eta 0:00:03
#      ----------------------------- ------- 454.8/567.8 MB 40.9 MB/s eta 0:00:03
#      ----------------------------- ------- 457.1/567.8 MB 54.4 MB/s eta 0:00:03
#      ----------------------------- ------- 459.4/567.8 MB 50.4 MB/s eta 0:00:03
#      ------------------------------ ------ 461.9/567.8 MB 50.4 MB/s eta 0:00:03
#      ------------------------------ ------ 464.1/567.8 MB 50.1 MB/s eta 0:00:03
#      ------------------------------ ------ 466.6/567.8 MB 54.7 MB/s eta 0:00:02
#      ------------------------------ ------ 468.5/567.8 MB 54.7 MB/s eta 0:00:02
#      ------------------------------ ------ 470.8/567.8 MB 54.7 MB/s eta 0:00:02
#      ------------------------------ ------ 473.3/567.8 MB 46.7 MB/s eta 0:00:03
#      ------------------------------- ----- 475.9/567.8 MB 46.7 MB/s eta 0:00:02
#      ------------------------------- ----- 477.5/567.8 MB 43.7 MB/s eta 0:00:03
#      ------------------------------- ----- 479.9/567.8 MB 46.9 MB/s eta 0:00:02
#      ------------------------------- ----- 482.6/567.8 MB 46.7 MB/s eta 0:00:02
#      ------------------------------- ----- 484.5/567.8 MB 50.4 MB/s eta 0:00:02
#      ------------------------------- ----- 485.7/567.8 MB 40.9 MB/s eta 0:00:03
#      ------------------------------- ----- 488.0/567.8 MB 46.7 MB/s eta 0:00:02
#      ------------------------------- ----- 488.5/567.8 MB 40.9 MB/s eta 0:00:02
#      ------------------------------- ----- 490.8/567.8 MB 40.9 MB/s eta 0:00:02
#      -------------------------------- ---- 493.2/567.8 MB 38.5 MB/s eta 0:00:02
#      -------------------------------- ---- 495.7/567.8 MB 43.7 MB/s eta 0:00:02
#      -------------------------------- ---- 497.9/567.8 MB 40.9 MB/s eta 0:00:02
#      -------------------------------- ---- 499.7/567.8 MB 50.4 MB/s eta 0:00:02
#      -------------------------------- ---- 501.4/567.8 MB 43.7 MB/s eta 0:00:02
#      -------------------------------- ---- 503.9/567.8 MB 43.5 MB/s eta 0:00:02
#      -------------------------------- ---- 505.1/567.8 MB 40.9 MB/s eta 0:00:02
#      -------------------------------- ---- 505.1/567.8 MB 34.4 MB/s eta 0:00:02
#      --------------------------------- --- 507.8/567.8 MB 36.4 MB/s eta 0:00:02
#      --------------------------------- --- 510.5/567.8 MB 38.5 MB/s eta 0:00:02
#      --------------------------------- --- 512.7/567.8 MB 40.9 MB/s eta 0:00:02
#      --------------------------------- --- 515.0/567.8 MB 40.9 MB/s eta 0:00:02
#      --------------------------------- --- 516.7/567.8 MB 46.9 MB/s eta 0:00:02
#      --------------------------------- --- 519.0/567.8 MB 46.7 MB/s eta 0:00:02
#      --------------------------------- --- 521.0/567.8 MB 46.7 MB/s eta 0:00:02
#      ---------------------------------- -- 522.7/567.8 MB 43.7 MB/s eta 0:00:02
#      ---------------------------------- -- 525.2/567.8 MB 43.5 MB/s eta 0:00:01
#      ---------------------------------- -- 527.2/567.8 MB 43.5 MB/s eta 0:00:01
#      ---------------------------------- -- 529.7/567.8 MB 50.4 MB/s eta 0:00:01
#      ---------------------------------- -- 531.8/567.8 MB 46.9 MB/s eta 0:00:01
#      ---------------------------------- -- 533.9/567.8 MB 43.7 MB/s eta 0:00:01
#      ---------------------------------- -- 536.1/567.8 MB 46.7 MB/s eta 0:00:01
#      ----------------------------------- - 538.1/567.8 MB 50.4 MB/s eta 0:00:01
#      ----------------------------------- - 539.9/567.8 MB 40.9 MB/s eta 0:00:01
#      ----------------------------------- - 542.2/567.8 MB 43.5 MB/s eta 0:00:01
#      ----------------------------------- - 544.2/567.8 MB 43.5 MB/s eta 0:00:01
#      ----------------------------------- - 546.8/567.8 MB 46.7 MB/s eta 0:00:01
#      ----------------------------------- - 548.2/567.8 MB 40.9 MB/s eta 0:00:01
#      ----------------------------------- - 550.5/567.8 MB 46.9 MB/s eta 0:00:01
#      ------------------------------------  552.6/567.8 MB 46.7 MB/s eta 0:00:01
#      ------------------------------------  554.3/567.8 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  554.9/567.8 MB 43.5 MB/s eta 0:00:01
#      ------------------------------------  554.9/567.8 MB 43.5 MB/s eta 0:00:01
#      ------------------------------------  556.2/567.8 MB 29.7 MB/s eta 0:00:01
#      ------------------------------------  557.8/567.8 MB 28.4 MB/s eta 0:00:01
#      ------------------------------------  560.1/567.8 MB 29.8 MB/s eta 0:00:01
#      ------------------------------------  561.3/567.8 MB 28.5 MB/s eta 0:00:01
#      ------------------------------------  562.6/567.8 MB 27.3 MB/s eta 0:00:01
#      ------------------------------------  564.8/567.8 MB 28.5 MB/s eta 0:00:01
#      ------------------------------------  566.7/567.8 MB 38.5 MB/s eta 0:00:01
#      ------------------------------------  567.3/567.8 MB 34.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  567.8/567.8 MB 36.4 MB/s eta 0:00:01
#      -------------------------------------- 567.8/567.8 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\dharm\anaconda3\lib\site-packages (from de-core-news-lg==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\dharm\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dharm\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dharm\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dharm\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dharm\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\dharm\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\dharm\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (0.1.4)
# Requirement already satisfied: colorama in c:\users\dharm\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\dharm\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\dharm\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dharm\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->de-core-news-lg==3.7.0) (2.1.1)
# Installing collected packages: de-core-news-lg
# Successfully installed de-core-news-lg-3.7.0
# [+] Download and installation successful
# You can now load the package via spacy.load('de_core_news_lg')

# %%
from bs4 import BeautifulSoup
import requests
import re

def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')  # Change 'html5lib' to 'html.parser'
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

ny_bb = url_to_string('https://www.sueddeutsche.de/sport/kroos-dfb-frankreich-nagelsmann-deutschland-1.6484717?reduced=true')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 90

# %% [markdown]
# ## Have a Look At The NERS

# %%
# Visualize named entities in the article using displacy
from spacy import displacy
displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deutschland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  und das 2:0 gegen
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Frankreich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Toni Kroos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , der Große  - Sport -
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SZ.de
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Zum Hauptinhalt springenSZ.deZeitungMagazinJetztDossierAlle SZ-Produkte LoginMenüMenüSuchenSüddeutsche ZeitungJetzt
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     abonnierenLoginMenüMenüSuchenSüddeutsche ZeitungMeine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  SZSZ PlusUkraineIsraelPolitikWirtschaftMeinungPanoramaSportMünchenKulturMedienBayernReportageGesellschaftStilWissenKarriereGesundheitBildungReiseAutomehr HomeSportFußballDeutsche
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NationalmannschaftDeutschland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  und das 2:0 gegen
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Frankreich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Toni Kroos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , der
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Große DFB-Team
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Toni
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , der
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Große24.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  März 2024, 13:01 UhrDetailansicht
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     öffnenGuter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Start:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Toni Kroos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  bereitet das 1:0 von
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Florian Wirtz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  vom Anstoßpunkt aus vor. (Foto:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alexander Hassenstein
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# /
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Getty Images
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# )Was für eine Rückkehr: Beim 2:0 gegen
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Frankreich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  zeigt die Nationalelf ihr bestes Spiel seit Jahren. Das liegt maßgeblich an
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Toni Kroos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  - der von seinen Mitspielern mit Lob überschüttet wird und mit 34 Jahren so sehr als Chef auftritt wie selten zuvor.Von
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Philipp Selldorf
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LyonAls Toni Kroos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  ein paar Minuten vor Schluss den Rasen verließ, um
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Waldemar Anton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  den Platz zu überlassen, empfing ihn nicht nur der Applaus der Mitspieler, Trainer und Betreuer, sondern auch der Beifall der
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     französischen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  Zuschauer. Wenn es nicht gegen die Etikette verstoßen hätte, dann hätte ihm wohl auch
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Didier Deschamps
#     <span style="font-size: 0.8em; fo

# %% [markdown]
# ## Popular NER Types

# %%
# Count the frequency of each named entity label in the article
from collections import Counter
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'ORG': 44, 'MISC': 25, 'PER': 20, 'LOC': 1})

# %% [markdown]
# ## Most Popular NER

# %%
# Extract the text of each named entity in the article and count the most common 5 entities
items = [x.text for x in article.ents]
Counter(items).most_common(5)
# Out:
# [('eBay', 5),
#  ('Toni Kroos', 4),
#  ('Frankreich', 3),
#  ('deutschen', 2),
#  ('FARFETCH', 2)]

# %% [markdown]
# ## Let’s Pick One Sentence to Analyze

# %%
# Extract sentences from the article and print the first sentence
sentences = [x for x in article.sents]
print(sentences[0])
# Out:
# Deutschland und das 2:0 gegen Frankreich: Toni Kroos, der Große  - Sport - SZ.de

# %% [markdown]
# ## NER Tags

# %%
# Visualize named entities in the first sentence of the article
displacy.render(nlp(str(sentences[0])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deutschland
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  und das 2:0 gegen
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Frankreich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# :
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Toni Kroos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , der Große  - Sport -
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SZ.de
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div></span>

# %% [markdown]
# ## Types of Words in Sentence

# %%
# Extract orthographic form, part-of-speech, and lemma of non-stopword, non-punctuation tokens in the first sentence
[(x.orth_,x.pos_, x.lemma_) for x in [y
                                      for y
                                      in nlp(str(sentences[0]))
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Deutschland', 'PROPN', 'Deutschland'),
#  ('2:0', 'NOUN', '2:0'),
#  ('Frankreich', 'PROPN', 'Frankreich'),
#  ('Toni', 'PROPN', 'Toni'),
#  ('Kroos', 'PROPN', 'Kroos'),
#  (' ', 'SPACE', ' '),
#  ('Sport', 'NOUN', 'Sport'),
#  ('SZ.de', 'PROPN', 'SZ.de')]

# %% [markdown]
# ## Sentence Dependency Tree

# %%
# Visualize dependency parse of the first sentence of the article with custom distance between words
displacy.render(nlp(str(sentences[0])), style='dep', jupyter = True,
                options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="de" id="f260f57b732c41949b5c23805df5c2e7-0" class="displacy" width="1610" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Deutschland</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">und</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">das</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">2:0</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">gegen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Frankreich:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Toni</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">Kroos,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">der</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">Große</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250"> -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">Sport -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">SZ.de</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f260f57b732c41949b5c23805df5c2e7-0-0" stroke-width="2px" d="M70,242.0 C70,182.0 155.0,182.0 155.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f260f57b732c41949b5c23805df5c2e7-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cd</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M155.0,244.0 L163.0,232.0 147.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f260f57b732c41949b5c23805df5c2e7-0-1" stroke-width="2px" d="M310,242.0 C310,182.0 395.0,182.0 395.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f260f57b732c41949b5c23805df5c2e7-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nk</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M310,244.0 L302,232.0 318,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f260f57b732c41949b5c23805df5c2e7-0-2" stroke-width="2px" d="M190,242.0 C190,122.0 400.0,122.0 400.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f260f57b732c41949b5c23805df5c2e7-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,244.0 L408.0,232.0 392.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f260f57b732c41949b5c23805df5c2e7-0-3" stroke-width="2px" d="M430,242.0 C430,182.0 515.0,182.0 515.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f260f57b732c41949b5c23805df5c2e7-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mnr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M515.0,244.0 L523.0,232.0 507.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f260f57b732c41949b5c23805df5c2e7-0-4" stroke-width="2px" d="M550,242.0 C550,182.0 635.0,182.0 635.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f260f57b732c41949b5c23805df5c2e7-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nk</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M635.0,244.0 L643.0,232.0 627.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f260f57b732c41949b5c23805df5c2e7-0-5" stroke-width="2px" d="M790,242.0 C790,182.0 875.0,182.0 875.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f260f57b732c41949b5c23805df5c2e7-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pnc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M790,244.0 L782,232.0 798,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f260f57b732c41949b5c23805df5c2e7-0-6" stroke-width="2px" d="M70,242.0 C70,62.0 885.0,62.0 885.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f260f57b732c41949b5c23805df5c2e7-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">par</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M885.0,244.0 L893.0,232.0 877.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f260f57b732c41949b5c23805df5c2e7-0-7" stroke-width="2px" d="M1030,242.0 C1030,182.0 1115.0,182.0 1115.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f260f57b732c41949b5c23805df5c2e7-0-7" class="displacy

# %% [markdown]
# # spacy 3

# %% [markdown]
# ## Import SpaCy in English

# %%
#!python -m spacy download en_core_web_lg 
import spacy
nlp = spacy.load("en_core_web_lg")

# %%
text = "My best friend gomez thinks like an introvert."
doc = nlp(text)
for token in doc:
    print(token, end=" | ")
# Out:
# My | best | friend | gomez | thinks | like | an | introvert | . |

# %% [markdown]
# ## What are the attributes that SpaCy adds?

# %%
import pandas as pd

def display_nlp(doc, include_punct=False):
    """Generate data frame for visualization of spaCy tokens."""
    rows = []
    for i, t in enumerate(doc):
        if not t.is_punct or include_punct:
            row = {'token': i,  'text': t.text, 'lemma_': t.lemma_, 
                   'is_stop': t.is_stop, 'is_alpha': t.is_alpha,
                   'pos_': t.pos_, 'dep_': t.dep_, 
                   'ent_type_': t.ent_type_, 'ent_iob_': t.ent_iob_}
            rows.append(row)
    
    df = pd.DataFrame(rows).set_index('token')
    df.index.name = None
    return df
display_nlp(doc)
# Out:
#         text     lemma_  is_stop  is_alpha   pos_   dep_ ent_type_ ent_iob_
# 0         My         my     True      True   PRON   poss                  O
# 1       best       good    False      True    ADJ   amod                  O
# 2     friend     friend    False      True   NOUN  nsubj                  O
# 3      gomez      gomez    False      True  PROPN  appos    PERSON        B
# 4     thinks      think    False      True   VERB   ROOT                  O
# 5       like       like    False      True    ADP   prep                  O
# 6         an         an     True      True    DET    det                  O
# 7  introvert  introvert    False      True   NOUN   pobj                  O

# %% [markdown]
# ## Removing Stop words using Spacy

# %%
text = "Dear venkat, we need to get a new playstation. Regards, tej"
doc = nlp(text)

non_stop = [t for t in doc if not t.is_stop and not t.is_punct]
print(non_stop)
# Out:
# [Dear, venkat, need, new, playstation, Regards, tej]

# %% [markdown]
# ## Find all nouns using Spacy

# %%
text = "My best friend gomez thinks like an introvert."
doc = nlp(text)

nouns = [t for t in doc if t.pos_ in ['NOUN', 'PROPN']]
print(nouns)
# Out:
# [friend, gomez, introvert]

# %% [markdown]
# ## Named Entity Recognition

# %%
text = "My best friend gomez thinks like an introvert."
doc = nlp(text)

for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (gomez, PERSON)

# %%
text = "Sarah Patel, CEO of Tech Innovations Ltd, resides in Silicon Valley." 
doc = nlp(text)

for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (Sarah Patel, PERSON) (Tech Innovations Ltd, ORG) (Silicon Valley, LOC)

# %% [markdown]
# ## Visualize NERS

# %%
from spacy import displacy

displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sarah Patel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , CEO of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tech Innovations Ltd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , resides in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Silicon Valley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .</div></span>

# %%
# !pip install html5lib
# Out:
# Requirement already satisfied: html5lib in c:\users\dharm\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\dharm\anaconda3\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\dharm\anaconda3\lib\site-packages (from html5lib) (0.5.1)

# %% [markdown]
# ## trying it on a real dataset

# %%
from bs4 import BeautifulSoup
import requests
import re

def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'lxml')  # Use 'lxml' parser instead of 'html5lib'
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

ny_bb = url_to_string('https://www.thomsonreuters.com/en.html')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 140

# %% [markdown]
# ## look at the NERS

# %%
displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Home | Thomson Reuters Skip
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to main content
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Legal Tax &amp; Accounting Trade &amp; Supply Risk &amp; Fraud News &amp; Media Books Developers Back Legal Business development
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# Billing management software
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Court
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  management software Legal calendaring solutions
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Practice management &amp; growth Project &amp; knowledge
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  management Workflow automation software
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Corporate &amp; business organization
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#                                   Business practice &amp; procedure Legal forms                                  Legal form-building software
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Legal data &amp; document
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  management                                  Data management Data-driven insights
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Document management Document storage &amp; retrieval Drafting
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
#  software, service &amp; guidance                                  Contract services Drafting software Evidence                                  Electronic evidence Financial management                                  Outside counsel spend
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Law
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  firm marketing                                  Attracting &amp; retaining clients
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Custom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  legal marketing services
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Legal research &amp;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  guidance                                  Anywhere access to reference books Due diligence Legal research technology Trial readiness, process &amp; case guidance                                  Case management software
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Matter management
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Recommended Products                     Westlaw                      Conduct legal research efficiently and confidently using trusted content, proprietary editorial enhancements, and advanced technology.                     Practical Law                      Fast track case onboarding and practice with confidence. Tap into a team of experts who create and maintain timely, reliable, and accurate resources so you can jumpstart your work.                      HighQ                      A business management tool for legal professionals that automates workflow. Simplify project management, increase profits, and improve client satisfaction.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Insights                              Book
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  store                              All products              Questions? We are here to help
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Contact us Back Tax &amp; Accounting Audit &amp; accounting                                  Accounting &amp; financial management
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Audit workflow Disclosure Engagement compilation &amp; review Guidance &amp; standards
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Internal audit &amp; controls Quality control Data &amp; document
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  management                                  Certificate management
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Data management &amp; mining Document management Document storage &amp; organization Estate planning                                  Estate planning &amp; taxation Wealth management Financial planning &amp; analysis                                  Financial reporting Payroll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , compensation,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pension &amp; benefits                                  Payroll &amp; workforce management services
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Healthcare
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  plan

# %% [markdown]
# ## Most popular NER types

# %%
from collections import Counter

labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'ORG': 91,
#          'DATE': 28,
#          'PRODUCT': 6,
#          'GPE': 5,
#          'LAW': 4,
#          'CARDINAL': 3,
#          'PERSON': 1,
#          'WORK_OF_ART': 1,
#          'FAC': 1})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(5)
# Out:
# [('today', 10),
#  ('Thomson Reuters', 8),
#  ('tomorrow', 6),
#  ('AI', 5),
#  ('Insights                              Book', 4)]

# %% [markdown]
# ## Let’s pick one sentence to analyze

# %%
article = nlp(ny_bb)
sentences = [x for x in article.sents]
print(sentences[2])
# Out:
# Practical Law                      Fast track case onboarding and practice with confidence.

# %% [markdown]
# ## NER tags

# %%
displacy.render(nlp(str(sentences[1])), jupyter=True, style='ent')
# Out:
# C:\Users\dharm\anaconda3\Lib\site-packages\spacy\displacy\__init__.py:213: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Recommended Products                     Westlaw                      Conduct legal research efficiently and confidently using trusted content, proprietary editorial enhancements, and advanced technology.                     </div></span>

# %% [markdown]
# ## Types of words in the sentence

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[2])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Practical', 'PROPN', 'Practical'),
#  ('Law', 'PROPN', 'Law'),
#  ('                     ', 'SPACE', '                     '),
#  ('Fast', 'PROPN', 'Fast'),
#  ('track', 'NOUN', 'track'),
#  ('case', 'NOUN', 'case'),
#  ('onboarding', 'VERB', 'onboarde'),
#  ('practice', 'VERB', 'practice'),
#  ('confidence', 'NOUN', 'confidence')]

# %% [markdown]
# ## Sentence dependency tree

# %%
displacy.render(nlp(str(sentences[2])), style='dep', jupyter = True, options = {'distance': 100})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="d62c88f385fb47439e77cdd4f32273c4-0" class="displacy" width="1150" height="237.0" direction="ltr" style="max-width: none; height: 237.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Practical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">Law</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">                     </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">Fast</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">track</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">case</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">onboarding</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">practice</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="147.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">confidence.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d62c88f385fb47439e77cdd4f32273c4-0-0" stroke-width="2px" d="M70,102.0 C70,52.0 145.0,52.0 145.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d62c88f385fb47439e77cdd4f32273c4-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,104.0 L62,92.0 78,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d62c88f385fb47439e77cdd4f32273c4-0-1" stroke-width="2px" d="M170,102.0 C170,2.0 350.0,2.0 350.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d62c88f385fb47439e77cdd4f32273c4-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,104.0 L162,92.0 178,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d62c88f385fb47439e77cdd4f32273c4-0-2" stroke-width="2px" d="M170,102.0 C170,52.0 245.0,52.0 245.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d62c88f385fb47439e77cdd4f32273c4-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245.0,104.0 L253.0,92.0 237.0,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d62c88f385fb47439e77cdd4f32273c4-0-3" stroke-width="2px" d="M370,102.0 C370,52.0 445.0,52.0 445.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d62c88f385fb47439e77cdd4f32273c4-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,104.0 L362,92.0 378,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d62c88f385fb47439e77cdd4f32273c4-0-4" stroke-width="2px" d="M470,102.0 C470,52.0 545.0,52.0 545.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d62c88f385fb47439e77cdd4f32273c4-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M470,104.0 L462,92.0 478,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d62c88f385fb47439e77cdd4f32273c4-0-5" stroke-width="2px" d="M570,102.0 C570,52.0 645.0,52.0 645.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d62c88f385fb47439e77cdd4f32273c4-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570,104.0 L562,92.0 578,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d62c88f385fb47439e77cdd4f32273c4-0-6" stroke-width="2px" d="M670,102.0 C670,52.0 745.0,52.0 745.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d62c88f385fb47439e77cdd4f32273c4-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,104.0 L753.0,92.0 737.0,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d62c88f385fb47439e77cdd4f32273c4-0-7" stroke-width="2px" d="M670,102.0 C670,2.0 850.0,2.0 850.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-d62c88f385fb47439e77cdd4f32273c4-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M850.0,104.0 L858.0,92.0 842.0,92.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-d62c88f385fb47439e77cdd4f32273c4-0-8" stroke-width="2px" d="M870,102.0 C870,52.0 945.0,52.0 945.0,102.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xli
