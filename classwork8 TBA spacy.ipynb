# %% [markdown]
# # Named Entity Recognition
#
# # DHARMATEJ VAYINENI (0937480)

# %% [markdown]
# # Importing libraries

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\dharm\anaconda3\lib\site-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\dharm\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dharm\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dharm\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dharm\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dharm\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\dharm\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\dharm\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: colorama in c:\users\dharm\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\dharm\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\dharm\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dharm\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ---------------------------------------- 0.0/587.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/587.7 MB ? eta -:--:--
#      -------------------------------------- 0.1/587.7 MB 544.7 kB/s eta 0:17:59
#      ---------------------------------------- 0.3/587.7 MB 1.7 MB/s eta 0:05:38
#      ---------------------------------------- 1.6/587.7 MB 8.8 MB/s eta 0:01:07
#      --------------------------------------- 3.8/587.7 MB 17.3 MB/s eta 0:00:34
#      --------------------------------------- 5.7/587.7 MB 20.4 MB/s eta 0:00:29
#      --------------------------------------- 5.7/587.7 MB 20.4 MB/s eta 0:00:29
#       -------------------------------------- 8.5/587.7 MB 23.7 MB/s eta 0:00:25
#       -------------------------------------- 9.5/587.7 MB 23.5 MB/s eta 0:00:25
#       ------------------------------------- 11.3/587.7 MB 34.4 MB/s eta 0:00:17
#       ------------------------------------- 12.3/587.7 MB 32.7 MB/s eta 0:00:18
#       ------------------------------------- 14.2/587.7 MB 31.2 MB/s eta 0:00:19
#      - ------------------------------------ 17.2/587.7 MB 38.6 MB/s eta 0:00:15
#      - ------------------------------------ 19.7/587.7 MB 40.9 MB/s eta 0:00:14
#      - ------------------------------------ 21.9/587.7 MB 46.7 MB/s eta 0:00:13
#      - ------------------------------------ 22.3/587.7 MB 38.5 MB/s eta 0:00:15
#      - ------------------------------------ 25.0/587.7 MB 46.7 MB/s eta 0:00:13
#      - ------------------------------------ 27.0/587.7 MB 38.6 MB/s eta 0:00:15
#      - ------------------------------------ 28.8/587.7 MB 38.6 MB/s eta 0:00:15
#      -- ----------------------------------- 31.3/587.7 MB 38.5 MB/s eta 0:00:15
#      -- ----------------------------------- 32.5/587.7 MB 43.7 MB/s eta 0:00:13
#      -- ----------------------------------- 33.6/587.7 MB 36.4 MB/s eta 0:00:16
#      -- ----------------------------------- 35.5/587.7 MB 38.5 MB/s eta 0:00:15
#      -- ----------------------------------- 38.1/587.7 MB 40.9 MB/s eta 0:00:14
#      -- ----------------------------------- 40.0/587.7 MB 40.9 MB/s eta 0:00:14
#      -- ----------------------------------- 42.3/587.7 MB 38.6 MB/s eta 0:00:15
#      -- ----------------------------------- 44.6/587.7 MB 46.7 MB/s eta 0:00:12
#      --- ---------------------------------- 47.1/587.7 MB 50.4 MB/s eta 0:00:11
#      --- ---------------------------------- 48.8/587.7 MB 46.7 MB/s eta 0:00:12
#      --- ---------------------------------- 49.2/587.7 MB 43.5 MB/s eta 0:00:13
#      --- ---------------------------------- 51.4/587.7 MB 43.7 MB/s eta 0:00:13
#      --- ---------------------------------- 53.0/587.7 MB 38.5 MB/s eta 0:00:14
#      --- ---------------------------------- 54.0/587.7 MB 36.4 MB/s eta 0:00:15
#      --- ---------------------------------- 54.3/587.7 MB 34.4 MB/s eta 0:00:16
#      --- ---------------------------------- 56.7/587.7 MB 29.7 MB/s eta 0:00:18
#      --- ---------------------------------- 58.4/587.7 MB 29.7 MB/s eta 0:00:18
#      --- ---------------------------------- 60.2/587.7 MB 34.4 MB/s eta 0:00:16
#      --- ---------------------------------- 61.8/587.7 MB 32.8 MB/s eta 0:00:17
#      ---- --------------------------------- 62.4/587.7 MB 29.7 MB/s eta 0:00:18
#      ---- --------------------------------- 64.6/587.7 MB 38.5 MB/s eta 0:00:14
#      ---- --------------------------------- 66.0/587.7 MB 34.6 MB/s eta 0:00:16
#      ---- --------------------------------- 67.7/587.7 MB 31.2 MB/s eta 0:00:17
#      ---- --------------------------------- 69.3/587.7 MB 32.8 MB/s eta 0:00:16
#      ---- --------------------------------- 70.1/587.7 MB 31.2 MB/s eta 0:00:17
#      ---- --------------------------------- 71.8/587.7 MB 29.7 MB/s eta 0:00:18
#      ---- --------------------------------- 74.3/587.7 MB 34.6 MB/s eta 0:00:15
#      ---- --------------------------------- 75.8/587.7 MB 34.4 MB/s eta 0:00:15
#      ----- -------------------------------- 77.9/587.7 MB 36.4 MB/s eta 0:00:15
#      ----- -------------------------------- 79.8/587.7 MB 38.5 MB/s eta 0:00:14
#      ----- -------------------------------- 80.8/587.7 MB 38.6 MB/s eta 0:00:14
#      ----- -------------------------------- 82.4/587.7 MB 36.4 MB/s eta 0:00:14
#      ----- -------------------------------- 84.9/587.7 MB 38.5 MB/s eta 0:00:14
#      ----- -------------------------------- 87.6/587.7 MB 40.9 MB/s eta 0:00:13
#      ----- -------------------------------- 88.5/587.7 MB 36.4 MB/s eta 0:00:14
#      ----- -------------------------------- 90.1/587.7 MB 36.4 MB/s eta 0:00:14
#      ----- -------------------------------- 92.5/587.7 MB 43.7 MB/s eta 0:00:12
#      ------ ------------------------------- 93.7/587.7 MB 40.9 MB/s eta 0:00:13
#      ------ ------------------------------- 96.5/587.7 MB 38.5 MB/s eta 0:00:13
#      ------ ------------------------------- 97.9/587.7 MB 40.9 MB/s eta 0:00:12
#      ------ ------------------------------- 98.2/587.7 MB 40.9 MB/s eta 0:00:12
#      ------ ------------------------------ 100.8/587.7 MB 36.3 MB/s eta 0:00:14
#      ------ ------------------------------ 102.4/587.7 MB 36.4 MB/s eta 0:00:14
#      ------ ------------------------------ 103.7/587.7 MB 34.4 MB/s eta 0:00:15
#      ------ ------------------------------ 105.5/587.7 MB 34.4 MB/s eta 0:00:15
#      ------ ------------------------------ 108.3/587.7 MB 36.4 MB/s eta 0:00:14
#      ------ ------------------------------ 109.4/587.7 MB 43.7 MB/s eta 0:00:11
#      ------ ------------------------------ 110.6/587.7 MB 36.4 MB/s eta 0:00:14
#      ------- ----------------------------- 113.8/587.7 MB 43.5 MB/s eta 0:00:11
#      ------- ----------------------------- 115.6/587.7 MB 46.7 MB/s eta 0:00:11
#      ------- ----------------------------- 117.7/587.7 MB 43.5 MB/s eta 0:00:11
#      ------- ----------------------------- 119.8/587.7 MB 54.4 MB/s eta 0:00:09
#      ------- ----------------------------- 121.2/587.7 MB 50.4 MB/s eta 0:00:10
#      ------- ----------------------------- 123.8/587.7 MB 43.7 MB/s eta 0:00:11
#      ------- ----------------------------- 125.9/587.7 MB 43.7 MB/s eta 0:00:11
#      ------- ----------------------------- 126.9/587.7 MB 38.6 MB/s eta 0:00:12
#      -------- ---------------------------- 128.1/587.7 MB 36.4 MB/s eta 0:00:13
#      -------- ---------------------------- 129.8/587.7 MB 38.6 MB/s eta 0:00:12
#      -------- ---------------------------- 132.2/587.7 MB 40.9 MB/s eta 0:00:12
#      -------- ---------------------------- 134.4/587.7 MB 36.3 MB/s eta 0:00:13
#      -------- ---------------------------- 136.5/587.7 MB 36.3 MB/s eta 0:00:13
#      -------- ---------------------------- 139.3/587.7 MB 46.9 MB/s eta 0:00:10
#      -------- ---------------------------- 140.9/587.7 MB 50.4 MB/s eta 0:00:09
#      --------- --------------------------- 143.0/587.7 MB 46.7 MB/s eta 0:00:10
#      --------- --------------------------- 145.2/587.7 MB 46.7 MB/s eta 0:00:10
#      --------- --------------------------- 145.2/587.7 MB 46.7 MB/s eta 0:00:10
#      --------- --------------------------- 147.3/587.7 MB 43.5 MB/s eta 0:00:11
#      --------- --------------------------- 147.3/587.7 MB 32.7 MB/s eta 0:00:14
#      --------- --------------------------- 148.2/587.7 MB 29.7 MB/s eta 0:00:15
#      --------- --------------------------- 149.6/587.7 MB 27.3 MB/s eta 0:00:17
#      --------- --------------------------- 150.9/587.7 MB 26.2 MB/s eta 0:00:17
#      --------- --------------------------- 152.6/587.7 MB 26.2 MB/s eta 0:00:17
#      --------- --------------------------- 152.9/587.7 MB 26.2 MB/s eta 0:00:17
#      --------- --------------------------- 155.7/587.7 MB 28.5 MB/s eta 0:00:16
#      --------- --------------------------- 157.7/587.7 MB 34.4 MB/s eta 0:00:13
#      ---------- -------------------------- 159.8/587.7 MB 36.3 MB/s eta 0:00:12
#      ---------- -------------------------- 162.5/587.7 MB 43.5 MB/s eta 0:00:10
#      ---------- -------------------------- 164.8/587.7 MB 50.4 MB/s eta 0:00:09
#      ---------- -------------------------- 166.3/587.7 MB 43.7 MB/s eta 0:00:10
#      ---------- -------------------------- 168.6/587.7 MB 43.5 MB/s eta 0:00:10
#      ---------- -------------------------- 170.6/587.7 MB 46.7 MB/s eta 0:00:09
#      ---------- -------------------------- 172.7/587.7 MB 40.9 MB/s eta 0:00:11
#      ---------- -------------------------- 174.4/587.7 MB 40.9 MB/s eta 0:00:11
#      ----------- ------------------------- 176.3/587.7 MB 40.9 MB/s eta 0:00:11
#      ----------- ------------------------- 178.5/587.7 MB 40.9 MB/s eta 0:00:10
#      ----------- ------------------------- 180.0/587.7 MB 38.5 MB/s eta 0:00:11
#      ----------- ------------------------- 181.6/587.7 MB 40.9 MB/s eta 0:00:10
#      ----------- ------------------------- 183.0/587.7 MB 36.4 MB/s eta 0:00:12
#      ----------- ------------------------- 184.6/587.7 MB 36.3 MB/s eta 0:00:12
#      ----------- ------------------------- 185.6/587.7 MB 34.4 MB/s eta 0:00:12
#      ----------- ------------------------- 187.6/587.7 MB 34.4 MB/s eta 0:00:12
#      ----------- ------------------------- 189.9/587.7 MB 34.4 MB/s eta 0:00:12
#      ------------ ------------------------ 192.0/587.7 MB 36.4 MB/s eta 0:00:11
#      ------------ ------------------------ 193.4/587.7 MB 36.4 MB/s eta 0:00:11
#      ------------ ------------------------ 195.8/587.7 MB 40.9 MB/s eta 0:00:10
#      ------------ ------------------------ 198.2/587.7 MB 43.5 MB/s eta 0:00:09
#      ------------ ------------------------ 199.2/587.7 MB 43.7 MB/s eta 0:00:09
#      ------------ ------------------------ 199.2/587.7 MB 43.7 MB/s eta 0:00:09
#      ------------ ------------------------ 202.4/587.7 MB 36.4 MB/s eta 0:00:11
#      ------------ ------------------------ 204.9/587.7 MB 38.6 MB/s eta 0:00:10
#      ------------ ------------------------ 206.0/587.7 MB 36.4 MB/s eta 0:00:11
#      ------------- ----------------------- 208.3/587.7 MB 36.4 MB/s eta 0:00:11
#      ------------- ----------------------- 210.5/587.7 MB 43.7 MB/s eta 0:00:09
#      ------------- ----------------------- 212.7/587.7 MB 43.5 MB/s eta 0:00:09
#      ------------- ----------------------- 212.9/587.7 MB 43.5 MB/s eta 0:00:09
#      ------------- ----------------------- 215.4/587.7 MB 38.5 MB/s eta 0:00:10
#      ------------- ----------------------- 217.8/587.7 MB 40.9 MB/s eta 0:00:10
#      ------------- ----------------------- 219.8/587.7 MB 43.5 MB/s eta 0:00:09
#      ------------- ----------------------- 221.5/587.7 MB 40.9 MB/s eta 0:00:09
#      -------------- ---------------------- 223.7/587.7 MB 46.7 MB/s eta 0:00:08
#      -------------- ---------------------- 225.2/587.7 MB 40.9 MB/s eta 0:00:09
#      -------------- ---------------------- 227.9/587.7 MB 40.9 MB/s eta 0:00:09
#      -------------- ---------------------- 230.1/587.7 MB 43.5 MB/s eta 0:00:09
#      -------------- ---------------------- 232.2/587.7 MB 43.5 MB/s eta 0:00:09
#      -------------- ---------------------- 233.0/587.7 MB 43.5 MB/s eta 0:00:09
#      -------------- ---------------------- 234.6/587.7 MB 40.9 MB/s eta 0:00:09
#      -------------- ---------------------- 236.8/587.7 MB 40.9 MB/s eta 0:00:09
#      -------------- ---------------------- 238.1/587.7 MB 36.4 MB/s eta 0:00:10
#      --------------- --------------------- 239.4/587.7 MB 34.4 MB/s eta 0:00:11
#      --------------- --------------------- 241.2/587.7 MB 34.4 MB/s eta 0:00:11
#      --------------- --------------------- 243.4/587.7 MB 36.3 MB/s eta 0:00:10
#      --------------- --------------------- 245.4/587.7 MB 38.5 MB/s eta 0:00:09
#      --------------- --------------------- 247.6/587.7 MB 40.9 MB/s eta 0:00:09
#      --------------- --------------------- 249.4/587.7 MB 43.7 MB/s eta 0:00:08
#      --------------- --------------------- 250.9/587.7 MB 40.9 MB/s eta 0:00:09
#      --------------- --------------------- 253.2/587.7 MB 43.7 MB/s eta 0:00:08
#      --------------- --------------------- 254.0/587.7 MB 43.5 MB/s eta 0:00:08
#      ---------------- -------------------- 256.1/587.7 MB 36.4 MB/s eta 0:00:10
#      ---------------- -------------------- 258.4/587.7 MB 36.4 MB/s eta 0:00:10
#      ---------------- -------------------- 260.2/587.7 MB 36.4 MB/s eta 0:00:09
#      ---------------- -------------------- 262.0/587.7 MB 36.4 MB/s eta 0:00:09
#      ---------------- -------------------- 264.8/587.7 MB 54.7 MB/s eta 0:00:06
#      ---------------- -------------------- 267.0/587.7 MB 50.4 MB/s eta 0:00:07
#      ---------------- -------------------- 269.1/587.7 MB 46.7 MB/s eta 0:00:07
#      ----------------- ------------------- 270.8/587.7 MB 46.7 MB/s eta 0:00:07
#      ----------------- ------------------- 272.9/587.7 MB 43.7 MB/s eta 0:00:08
#      ----------------- ------------------- 275.4/587.7 MB 43.7 MB/s eta 0:00:08
#      ----------------- ------------------- 276.8/587.7 MB 43.5 MB/s eta 0:00:08
#      ----------------- ------------------- 278.4/587.7 MB 40.9 MB/s eta 0:00:08
#      ----------------- ------------------- 280.6/587.7 MB 40.9 MB/s eta 0:00:08
#      ----------------- ------------------- 283.0/587.7 MB 43.5 MB/s eta 0:00:07
#      ----------------- ------------------- 284.9/587.7 MB 40.9 MB/s eta 0:00:08
#      ------------------ ------------------ 287.7/587.7 MB 46.7 MB/s eta 0:00:07
#      ------------------ ------------------ 289.8/587.7 MB 46.9 MB/s eta 0:00:07
#      ------------------ ------------------ 291.8/587.7 MB 46.9 MB/s eta 0:00:07
#      ------------------ ------------------ 294.0/587.7 MB 46.7 MB/s eta 0:00:07
#      ------------------ ------------------ 295.5/587.7 MB 46.9 MB/s eta 0:00:07
#      ------------------ ------------------ 298.2/587.7 MB 43.7 MB/s eta 0:00:07
#      ------------------ ------------------ 299.2/587.7 MB 43.7 MB/s eta 0:00:07
#      ------------------ ------------------ 300.4/587.7 MB 43.7 MB/s eta 0:00:07
#      ------------------- ----------------- 301.8/587.7 MB 34.4 MB/s eta 0:00:09
#      ------------------- ----------------- 304.9/587.7 MB 38.6 MB/s eta 0:00:08
#      ------------------- ----------------- 307.1/587.7 MB 40.9 MB/s eta 0:00:07
#      ------------------- ----------------- 309.6/587.7 MB 43.7 MB/s eta 0:00:07
#      ------------------- ----------------- 311.7/587.7 MB 54.7 MB/s eta 0:00:06
#      ------------------- ----------------- 313.7/587.7 MB 50.4 MB/s eta 0:00:06
#      ------------------- ----------------- 315.8/587.7 MB 46.7 MB/s eta 0:00:06
#      -------------------- ---------------- 318.0/587.7 MB 46.7 MB/s eta 0:00:06
#      -------------------- ---------------- 319.3/587.7 MB 40.9 MB/s eta 0:00:07
#      -------------------- ---------------- 322.1/587.7 MB 46.9 MB/s eta 0:00:06
#      -------------------- ---------------- 323.6/587.7 MB 46.7 MB/s eta 0:00:06
#      -------------------- ---------------- 324.6/587.7 MB 40.9 MB/s eta 0:00:07
#      -------------------- ---------------- 327.0/587.7 MB 40.9 MB/s eta 0:00:07
#      -------------------- ---------------- 329.6/587.7 MB 43.7 MB/s eta 0:00:06
#      -------------------- ---------------- 330.7/587.7 MB 38.6 MB/s eta 0:00:07
#      -------------------- ---------------- 333.2/587.7 MB 40.9 MB/s eta 0:00:07
#      --------------------- --------------- 335.3/587.7 MB 46.7 MB/s eta 0:00:06
#      --------------------- --------------- 337.5/587.7 MB 43.7 MB/s eta 0:00:06
#      --------------------- --------------- 339.8/587.7 MB 40.9 MB/s eta 0:00:07
#      --------------------- --------------- 341.8/587.7 MB 46.7 MB/s eta 0:00:06
#      --------------------- --------------- 344.0/587.7 MB 46.7 MB/s eta 0:00:06
#      --------------------- --------------- 346.0/587.7 MB 46.7 MB/s eta 0:00:06
#      --------------------- --------------- 347.5/587.7 MB 43.5 MB/s eta 0:00:06
#      ---------------------- -------------- 349.5/587.7 MB 40.9 MB/s eta 0:00:06
#      ---------------------- -------------- 352.3/587.7 MB 43.7 MB/s eta 0:00:06
#      ---------------------- -------------- 354.1/587.7 MB 43.7 MB/s eta 0:00:06
#      ---------------------- -------------- 356.4/587.7 MB 43.7 MB/s eta 0:00:06
#      ---------------------- -------------- 357.8/587.7 MB 43.5 MB/s eta 0:00:06
#      ---------------------- -------------- 360.4/587.7 MB 43.5 MB/s eta 0:00:06
#      ---------------------- -------------- 362.7/587.7 MB 46.7 MB/s eta 0:00:05
#      ---------------------- -------------- 364.0/587.7 MB 40.9 MB/s eta 0:00:06
#      ----------------------- ------------- 366.4/587.7 MB 43.7 MB/s eta 0:00:06
#      ----------------------- ------------- 369.0/587.7 MB 46.7 MB/s eta 0:00:05
#      ----------------------- ------------- 371.1/587.7 MB 46.7 MB/s eta 0:00:05
#      ----------------------- ------------- 373.1/587.7 MB 46.7 MB/s eta 0:00:05
#      ----------------------- ------------- 374.9/587.7 MB 43.5 MB/s eta 0:00:05
#      ----------------------- ------------- 376.5/587.7 MB 46.7 MB/s eta 0:00:05
#      ----------------------- ------------- 377.4/587.7 MB 38.5 MB/s eta 0:00:06
#      ----------------------- ------------- 379.8/587.7 MB 36.4 MB/s eta 0:00:06
#      ------------------------ ------------ 381.3/587.7 MB 36.4 MB/s eta 0:00:06
#      ------------------------ ------------ 383.3/587.7 MB 36.4 MB/s eta 0:00:06
#      ------------------------ ------------ 385.3/587.7 MB 36.4 MB/s eta 0:00:06
#      ------------------------ ------------ 387.8/587.7 MB 43.7 MB/s eta 0:00:05
#      ------------------------ ------------ 390.3/587.7 MB 43.7 MB/s eta 0:00:05
#      ------------------------ ------------ 392.4/587.7 MB 46.7 MB/s eta 0:00:05
#      ------------------------ ------------ 394.5/587.7 MB 50.1 MB/s eta 0:00:04
#      ------------------------ ------------ 396.6/587.7 MB 50.4 MB/s eta 0:00:04
#      ------------------------- ----------- 398.7/587.7 MB 43.7 MB/s eta 0:00:05
#      ------------------------- ----------- 399.0/587.7 MB 43.5 MB/s eta 0:00:05
#      ------------------------- ----------- 399.1/587.7 MB 32.7 MB/s eta 0:00:06
#      ------------------------- ----------- 402.7/587.7 MB 36.3 MB/s eta 0:00:06
#      ------------------------- ----------- 404.6/587.7 MB 36.4 MB/s eta 0:00:06
#      ------------------------- ----------- 406.4/587.7 MB 36.3 MB/s eta 0:00:05
#      ------------------------- ----------- 408.1/587.7 MB 32.8 MB/s eta 0:00:06
#      ------------------------- ----------- 410.0/587.7 MB 43.7 MB/s eta 0:00:05
#      ------------------------- ----------- 411.5/587.7 MB 38.5 MB/s eta 0:00:05
#      ------------------------- ----------- 412.5/587.7 MB 36.4 MB/s eta 0:00:05
#      -------------------------- ---------- 413.9/587.7 MB 34.4 MB/s eta 0:00:06
#      -------------------------- ---------- 415.2/587.7 MB 31.1 MB/s eta 0:00:06
#      -------------------------- ---------- 416.1/587.7 MB 28.5 MB/s eta 0:00:07
#      -------------------------- ---------- 417.7/587.7 MB 29.8 MB/s eta 0:00:06
#      -------------------------- ---------- 420.1/587.7 MB 31.2 MB/s eta 0:00:06
#      -------------------------- ---------- 422.3/587.7 MB 32.8 MB/s eta 0:00:06
#      -------------------------- ---------- 424.1/587.7 MB 36.4 MB/s eta 0:00:05
#      -------------------------- ---------- 424.7/587.7 MB 36.3 MB/s eta 0:00:05
#      -------------------------- ---------- 424.7/587.7 MB 28.4 MB/s eta 0:00:06
#      -------------------------- ---------- 426.3/587.7 MB 31.1 MB/s eta 0:00:06
#      -------------------------- ---------- 428.3/587.7 MB 32.8 MB/s eta 0:00:05
#      --------------------------- --------- 430.8/587.7 MB 32.8 MB/s eta 0:00:05
#      --------------------------- --------- 433.3/587.7 MB 32.8 MB/s eta 0:00:05
#      --------------------------- --------- 435.1/587.7 MB 46.7 MB/s eta 0:00:04
#      --------------------------- --------- 437.1/587.7 MB 46.7 MB/s eta 0:00:04
#      --------------------------- --------- 438.3/587.7 MB 46.7 MB/s eta 0:00:04
#      --------------------------- --------- 439.0/587.7 MB 40.9 MB/s eta 0:00:04
#      --------------------------- --------- 440.5/587.7 MB 34.4 MB/s eta 0:00:05
#      --------------------------- --------- 442.7/587.7 MB 34.6 MB/s eta 0:00:05
#      --------------------------- --------- 443.7/587.7 MB 32.7 MB/s eta 0:00:05
#      ---------------------------- -------- 445.3/587.7 MB 31.2 MB/s eta 0:00:05
#      ---------------------------- -------- 448.0/587.7 MB 32.8 MB/s eta 0:00:05
#      ---------------------------- -------- 450.6/587.7 MB 40.9 MB/s eta 0:00:04
#      ---------------------------- -------- 452.7/587.7 MB 40.9 MB/s eta 0:00:04
#      ---------------------------- -------- 454.4/587.7 MB 43.7 MB/s eta 0:00:04
#      ---------------------------- -------- 456.4/587.7 MB 46.7 MB/s eta 0:00:03
#      ---------------------------- -------- 459.0/587.7 MB 43.7 MB/s eta 0:00:03
#      ---------------------------- -------- 460.5/587.7 MB 43.7 MB/s eta 0:00:03
#      ----------------------------- ------- 463.1/587.7 MB 43.5 MB/s eta 0:00:03
#      ----------------------------- ------- 465.2/587.7 MB 43.5 MB/s eta 0:00:03
#      ----------------------------- ------- 466.9/587.7 MB 43.5 MB/s eta 0:00:03
#      ----------------------------- ------- 469.4/587.7 MB 43.7 MB/s eta 0:00:03
#      ----------------------------- ------- 471.5/587.7 MB 46.9 MB/s eta 0:00:03
#      ----------------------------- ------- 473.6/587.7 MB 43.7 MB/s eta 0:00:03
#      ----------------------------- ------- 475.7/587.7 MB 43.7 MB/s eta 0:00:03
#      ------------------------------ ------ 476.6/587.7 MB 38.5 MB/s eta 0:00:03
#      ------------------------------ ------ 477.6/587.7 MB 40.9 MB/s eta 0:00:03
#      ------------------------------ ------ 477.6/587.7 MB 40.9 MB/s eta 0:00:03
#      ------------------------------ ------ 479.8/587.7 MB 32.7 MB/s eta 0:00:04
#      ------------------------------ ------ 481.2/587.7 MB 29.8 MB/s eta 0:00:04
#      ------------------------------ ------ 481.2/587.7 MB 29.8 MB/s eta 0:00:04
#      ------------------------------ ------ 483.1/587.7 MB 26.2 MB/s eta 0:00:04
#      ------------------------------ ------ 484.9/587.7 MB 27.3 MB/s eta 0:00:04
#      ------------------------------ ------ 486.8/587.7 MB 27.3 MB/s eta 0:00:04
#      ------------------------------ ------ 489.6/587.7 MB 34.4 MB/s eta 0:00:03
#      ------------------------------ ------ 491.3/587.7 MB 36.3 MB/s eta 0:00:03
#      ------------------------------- ----- 493.8/587.7 MB 46.7 MB/s eta 0:00:03
#      ------------------------------- ----- 495.6/587.7 MB 46.9 MB/s eta 0:00:02
#      ------------------------------- ----- 496.4/587.7 MB 43.7 MB/s eta 0:00:03
#      ------------------------------- ----- 498.5/587.7 MB 40.9 MB/s eta 0:00:03
#      ------------------------------- ----- 500.7/587.7 MB 38.5 MB/s eta 0:00:03
#      ------------------------------- ----- 502.2/587.7 MB 38.5 MB/s eta 0:00:03
#      ------------------------------- ----- 504.7/587.7 MB 40.9 MB/s eta 0:00:03
#      ------------------------------- ----- 506.6/587.7 MB 43.5 MB/s eta 0:00:02
#      -------------------------------- ---- 508.7/587.7 MB 43.5 MB/s eta 0:00:02
#      -------------------------------- ---- 510.8/587.7 MB 43.7 MB/s eta 0:00:02
#      -------------------------------- ---- 512.9/587.7 MB 50.4 MB/s eta 0:00:02
#      -------------------------------- ---- 515.0/587.7 MB 43.7 MB/s eta 0:00:02
#      -------------------------------- ---- 515.7/587.7 MB 38.5 MB/s eta 0:00:02
#      -------------------------------- ---- 518.1/587.7 MB 38.5 MB/s eta 0:00:02
#      -------------------------------- ---- 520.0/587.7 MB 38.5 MB/s eta 0:00:02
#      -------------------------------- ---- 522.9/587.7 MB 40.9 MB/s eta 0:00:02
#      --------------------------------- --- 524.8/587.7 MB 40.9 MB/s eta 0:00:02
#      --------------------------------- --- 527.1/587.7 MB 46.9 MB/s eta 0:00:02
#      --------------------------------- --- 528.8/587.7 MB 43.7 MB/s eta 0:00:02
#      --------------------------------- --- 530.6/587.7 MB 46.7 MB/s eta 0:00:02
#      --------------------------------- --- 533.3/587.7 MB 43.7 MB/s eta 0:00:02
#      --------------------------------- --- 535.4/587.7 MB 43.7 MB/s eta 0:00:02
#      --------------------------------- --- 537.5/587.7 MB 46.7 MB/s eta 0:00:02
#      --------------------------------- --- 539.6/587.7 MB 46.7 MB/s eta 0:00:02
#      ---------------------------------- -- 541.6/587.7 MB 46.7 MB/s eta 0:00:01
#      ---------------------------------- -- 543.7/587.7 MB 43.7 MB/s eta 0:00:02
#      ---------------------------------- -- 545.8/587.7 MB 43.7 MB/s eta 0:00:01
#      ---------------------------------- -- 546.5/587.7 MB 38.6 MB/s eta 0:00:02
#      ---------------------------------- -- 546.9/587.7 MB 38.5 MB/s eta 0:00:02
#      ---------------------------------- -- 548.5/587.7 MB 32.7 MB/s eta 0:00:02
#      ---------------------------------- -- 549.2/587.7 MB 29.7 MB/s eta 0:00:02
#      ---------------------------------- -- 550.8/587.7 MB 28.4 MB/s eta 0:00:02
#      ---------------------------------- -- 552.5/587.7 MB 28.4 MB/s eta 0:00:02
#      ---------------------------------- -- 554.1/587.7 MB 27.3 MB/s eta 0:00:02
#      ----------------------------------- - 556.5/587.7 MB 31.2 MB/s eta 0:00:01
#      ----------------------------------- - 558.1/587.7 MB 34.4 MB/s eta 0:00:01
#      ----------------------------------- - 559.4/587.7 MB 36.4 MB/s eta 0:00:01
#      ----------------------------------- - 561.9/587.7 MB 38.5 MB/s eta 0:00:01
#      ----------------------------------- - 564.3/587.7 MB 43.5 MB/s eta 0:00:01
#      ----------------------------------- - 566.6/587.7 MB 43.5 MB/s eta 0:00:01
#      ----------------------------------- - 568.2/587.7 MB 43.5 MB/s eta 0:00:01
#      ----------------------------------- - 570.7/587.7 MB 46.7 MB/s eta 0:00:01
#      ----------------------------------- - 571.8/587.7 MB 43.7 MB/s eta 0:00:01
#      ------------------------------------  573.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  574.4/587.7 MB 34.4 MB/s eta 0:00:01
#      ------------------------------------  576.6/587.7 MB 34.4 MB/s eta 0:00:01
#      ------------------------------------  578.1/587.7 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  580.5/587.7 MB 34.4 MB/s eta 0:00:01
#      ------------------------------------  582.2/587.7 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------  584.0/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  586.0/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      ------------------------------------  587.7/587.7 MB 40.9 MB/s eta 0:00:01
#      -------------------------------------- 587.7/587.7 MB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\dharm\anaconda3\lib\site-packages (from en-core-web-lg==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\dharm\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\dharm\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dharm\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dharm\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dharm\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dharm\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\dharm\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\dharm\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\dharm\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\dharm\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\dharm\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dharm\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %% [markdown]
# ## Import SpaCy in English

# %%
#!python -m spacy download en_core_web_lg 
import spacy
nlp = spacy.load("en_core_web_lg")

# %%
text = "My best friend Ryan Peters likes fancy adventure games."
doc = nlp(text)
for token in doc:
    print(token, end=" | ")
# Out:
# My | best | friend | Ryan | Peters | likes | fancy | adventure | games | . |

# %% [markdown]
# ## What are the attributes that SpaCy adds?

# %%
import pandas as pd

def display_nlp(doc, include_punct=False):
    """Generate data frame for visualization of spaCy tokens."""
    rows = []
    for i, t in enumerate(doc):
        if not t.is_punct or include_punct:
            row = {'token': i,  'text': t.text, 'lemma_': t.lemma_, 
                   'is_stop': t.is_stop, 'is_alpha': t.is_alpha,
                   'pos_': t.pos_, 'dep_': t.dep_, 
                   'ent_type_': t.ent_type_, 'ent_iob_': t.ent_iob_}
            rows.append(row)
    
    df = pd.DataFrame(rows).set_index('token')
    df.index.name = None
    return df
display_nlp(doc)
# Out:
#         text     lemma_  is_stop  is_alpha   pos_      dep_ ent_type_ ent_iob_
# 0         My         my     True      True   PRON      poss                  O
# 1       best       good    False      True    ADJ      amod                  O
# 2     friend     friend    False      True   NOUN     nsubj                  O
# 3       Ryan       Ryan    False      True  PROPN  compound    PERSON        B
# 4     Peters     Peters    False      True  PROPN     appos    PERSON        I
# 5      likes       like    False      True   VERB      ROOT                  O
# 6      fancy      fancy    False      True    ADJ      amod                  O
# 7  adventure  adventure    False      True   NOUN  compound                  O
# 8      games       game    False      True   NOUN      dobj                  O

# %% [markdown]
# ## Removing Stop words using Spacy

# %%
text = "Dear Ryan, we need to sit down and talk. Regards, Pete"
doc = nlp(text)

non_stop = [t for t in doc if not t.is_stop and not t.is_punct]
print(non_stop)
# Out:
# [Dear, Ryan, need, sit, talk, Regards, Pete]

# %% [markdown]
# ## Find all nouns using Spacy

# %%
text = "My best friend Ryan Peters likes fancy adventure games."
doc = nlp(text)

nouns = [t for t in doc if t.pos_ in ['NOUN', 'PROPN']]
print(nouns)
# Out:
# [friend, Ryan, Peters, adventure, games]

# %% [markdown]
# ## Named Entity Recognition

# %%
text = "My best friend Ryan Peters likes fancy adventure games."
doc = nlp(text)

for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (Ryan Peters, PERSON)

# %%
text = "James O'Neill, chairman of World Cargo Inc, lives in San Francisco." 
doc = nlp(text)

for ent in doc.ents:
    print(f"({ent.text}, {ent.label_})", end=" ")
# Out:
# (James O'Neill, PERSON) (World Cargo Inc, ORG) (San Francisco, GPE)

# %% [markdown]
# ## Visualize NERS

# %%
from spacy import displacy

displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James O'Neill
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , chairman of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World Cargo Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , lives in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     San Francisco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</div></span>

# %%
# !pip install html5lib
# Out:
# Requirement already satisfied: html5lib in c:\users\dharm\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\dharm\anaconda3\lib\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\dharm\anaconda3\lib\site-packages (from html5lib) (0.5.1)

# %% [markdown]
# ## trying it on a real dataset

# %%
from bs4 import BeautifulSoup
import requests
import re

def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'lxml')  # Use 'lxml' parser instead of 'html5lib'
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

ny_bb = url_to_string('https://ieeexplore.ieee.org/Xplore/home.jsp')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 4

# %% [markdown]
# ## look at the NERS

# %%
displacy.render(article, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"> IEEE Xplore - Temporarily Unavailable
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IEEE.org IEEE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Xplore
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IEEE-SA IEEE Spectrum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  More Sites IEEE Xplore is temporarily unavailable We are working to restore service as soon as possible. Please try again later or email questions to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     onlinesupport@ieee.org
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .We apologize for the inconvenience and appreciate your patience.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Â© Copyright  IEEE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  - All rights reserved. </div></span>

# %% [markdown]
# ## Most popular NER types

# %%
from collections import Counter

labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'ORG': 2, 'CARDINAL': 1, 'PERSON': 1})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(5)
# Out:
# [('IEEE.org IEEE', 1),
#  ('IEEE-SA IEEE Spectrum', 1),
#  ('onlinesupport@ieee.org', 1),
#  ('Â© Copyright  IEEE', 1)]

# %% [markdown]
# ## Let’s pick one sentence to analyze

# %%
article = nlp(ny_bb)
sentences = [x for x in article.sents]
print(sentences[2])
# Out:
# We apologize for the inconvenience and appreciate your patience.

# %% [markdown]
# ## NER tags

# %%
displacy.render(nlp(str(sentences[1])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Please try again later or email questions to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     onlinesupport@ieee.org
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .</div></span>

# %% [markdown]
# ## Types of words in the sentence

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences[2])) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('apologize', 'VERB', 'apologize'),
#  ('inconvenience', 'NOUN', 'inconvenience'),
#  ('appreciate', 'VERB', 'appreciate'),
#  ('patience', 'NOUN', 'patience')]

# %% [markdown]
# ## Sentence dependency tree

# %%
displacy.render(nlp(str(sentences[2])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c64a14ca124c40dea278a79949bcc7a3-0" class="displacy" width="1130" height="377.0" direction="ltr" style="max-width: none; height: 377.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">apologize</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">inconvenience</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">appreciate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">your</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="287.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">patience.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c64a14ca124c40dea278a79949bcc7a3-0-0" stroke-width="2px" d="M70,242.0 C70,182.0 155.0,182.0 155.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c64a14ca124c40dea278a79949bcc7a3-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,244.0 L62,232.0 78,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c64a14ca124c40dea278a79949bcc7a3-0-1" stroke-width="2px" d="M190,242.0 C190,182.0 275.0,182.0 275.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c64a14ca124c40dea278a79949bcc7a3-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M275.0,244.0 L283.0,232.0 267.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c64a14ca124c40dea278a79949bcc7a3-0-2" stroke-width="2px" d="M430,242.0 C430,182.0 515.0,182.0 515.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c64a14ca124c40dea278a79949bcc7a3-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M430,244.0 L422,232.0 438,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c64a14ca124c40dea278a79949bcc7a3-0-3" stroke-width="2px" d="M310,242.0 C310,122.0 520.0,122.0 520.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c64a14ca124c40dea278a79949bcc7a3-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M520.0,244.0 L528.0,232.0 512.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c64a14ca124c40dea278a79949bcc7a3-0-4" stroke-width="2px" d="M190,242.0 C190,62.0 645.0,62.0 645.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c64a14ca124c40dea278a79949bcc7a3-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M645.0,244.0 L653.0,232.0 637.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c64a14ca124c40dea278a79949bcc7a3-0-5" stroke-width="2px" d="M190,242.0 C190,2.0 770.0,2.0 770.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c64a14ca124c40dea278a79949bcc7a3-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770.0,244.0 L778.0,232.0 762.0,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c64a14ca124c40dea278a79949bcc7a3-0-6" stroke-width="2px" d="M910,242.0 C910,182.0 995.0,182.0 995.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c64a14ca124c40dea278a79949bcc7a3-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M910,244.0 L902,232.0 918,232.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c64a14ca124c40dea278a79949bcc7a3-0-7" stroke-width="2px" d="M790,242.0 C790,122.0 1000.0,122.0 1000.0,242.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c64a14ca124c40dea278a79949bcc7a3-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1000.0,244.0 L1008.0,232.0 992.0,232.0" fill="currentColor"/>
# </g>
# </svg></span>
