# %% [markdown]
# # CS651 Text Based Analysis (Assignment 2)

# %%
import pandas as pd

# File path
file = "Lego Data.csv"

# Attempt to read the file using different encodings
encodings = ['utf-8', 'utf-8-sig', 'latin1', 'ISO-8859-1']
for encoding in encodings:
    try:
        df = pd.read_csv(file, encoding=encoding)
        print("File read successfully with encoding:", encoding)
        break
    except UnicodeDecodeError:
        print("UnicodeDecodeError encountered with encoding:", encoding)
        continue

# Display the first 20 rows of the DataFrame
df.head(20)
# Out:
# File read successfully with encoding: utf-8
#     Set_ID                        Name  Year          Theme    Theme_Group  \
# 0    659-1               Police Patrol  1975       LEGOLAND        Vintage
# 1    314-1               Police Launch  1976       LEGOLAND        Vintage
# 2    369-1         Coast Guard Station  1976       LEGOLAND        Vintage
# 3    485-1                  Fire Truck  1976       LEGOLAND        Vintage
# 4    787-1               Storage Cloth  1977          Basic          Basic
# 5   1124-1      Digger Bucket Assembly  1977  Service Packs  Miscellaneous
# 6   1151-1  Train Power Pick-Up Blocks  1977  Service Packs  Miscellaneous
# 7    642-1           Tow Truck and Car  1978           Town     Modern day
# 8    948-1                     Go-Kart  1978        Technic      Technical
# 9    551-1       Road Plates, Junction  1979           Town     Modern day
# 10   608-2                        Taxi  1979           Town     Modern day
# 11   646-1                Auto Service  1979           Town     Modern day
# 12  1115-1        Lighting Brick, 4.5V  1980  Service Packs  Miscellaneous
# 13  6305-1           Trees and Flowers  1980           Town     Modern day
# 14  6647-1              Highway Repair  1980           Town     Modern day
# 15  6679-2             Exxon Tow Truck  1980           Town     Modern day
# 16  7816-1          Shell Tanker Wagon  1980         Trains     Modern day
# 17  7818-1             Passenger Coach  1980         Trains     Modern day
# 18  7822-1             Railway Station  1980         Trains     Modern day
# 19  7850-1  8 Straight Rails Grey 4.5V  1980         Trains     Modern day
#
#            Subtheme Category        Packaging  Num_Instructions  \
# 0               NaN   Normal  {Not specified}                 0
# 1             Boats   Normal  {Not specified}                 0
# 2          Building   Normal  {Not specified}                 0
# 3               NaN   Normal  {Not specified}                 0
# 4   Supplementaries   Normal  {Not specified}                 0
# 5               NaN   Normal          Polybag                 0
# 6               NaN   Normal  {Not specified}                 0
# 7           Classic   Normal              Box                 0
# 8               NaN   Normal              Box                 0
# 9       Accessories   Normal   Shrink-wrapped                 0
# 10          Classic   Normal  {Not specified}                 0
# 11          Classic   Normal  {Not specified}                 0
# 12              NaN   Normal          Polybag                 0
# 13      Accessories   Normal              Box                 0
# 14      Maintenance   Normal              Box                 0
# 15         Vehicles   Normal              Box                 0
# 16          4.5/12V   Normal  {Not specified}                 0
# 17          4.5/12V   Normal  {Not specified}                 0
# 18          4.5/12V   Normal  {Not specified}                 0
# 19          4.5/12V   Normal  {Not specified}                 0
#
#         Availability  Pieces  Minifigures  Owned  Rating  USD_MSRP  \
# 0    {Not specified}    49.0          2.0    953     3.7       NaN
# 1    {Not specified}    53.0          2.0   1118     3.2       NaN
# 2    {Not specified}   275.0          5.0    462     0.0       NaN
# 3    {Not specified}    72.0          3.0    347     0.0       NaN
# 4    {Not specified}     1.0          NaN    235     0.0       NaN
# 5     LEGO exclusive     3.0          NaN     38     0.0       NaN
# 6    {Not specified}     2.0          NaN     24     0.0       NaN
# 7             Retail    44.0          NaN   1085     0.0       NaN
# 8             Retail   206.0          NaN    765     0.0       NaN
# 9             Retail     2.0          NaN    513     0.0       NaN
# 10   {Not specified}    25.0          1.0   1618     3.1       NaN
# 11   {Not specified}    43.0          1.0   1253     3.3       NaN
# 12    LEGO exclusive     1.0          NaN     60     0.0       NaN
# 13            Retail    12.0          NaN   1842     3.8       NaN
# 14            Retail    55.0          1.0   2166     3.9       NaN
# 15  Retail - limited    79.0          1.0    784     4.1       NaN
# 16   {Not specified}   120.0          1.0    559     0.0       NaN
# 17   {Not specified}   114.0          2.0    585     4.0       NaN
# 18   {Not specified}   384.0          3.0    806     4.1       NaN
# 19   {Not specified}    32.0          NaN   1122     3.9       NaN
#
#     Total_Quantity  Current_Price
# 0                1        55.0000
# 1                1       149.2976
# 2                1       250.0000
# 3                1       165.0000
# 4                1        90.0000
# 5                1         4.2500
# 6                3        17.0000
# 7                1       299.9900
# 8                1       349.9900
# 9                1        40.0000
# 10               1        99.9900
# 11               1       188.4539
# 12               2         5.9500
# 13               1        49.9900
# 14               1       222.5061
# 15               1       199.9900
# 16               1       189.9900
# 17               1       347.3200
# 18               1       389.9900
# 19               4        39.9900

# %% [markdown]
# ### sample method on dataframe

# %%
#frac=0.2 indicates that 20% of the rows should be selected
df=df.sample(frac=0.2)
print(df)
# Out:
#        Set_ID                                               Name  Year  \
# 3621  10871-1                                            Airport  2018
# 1291  10200-1                                  Custom Car Garage  2008
# 2736  41543-1                                               Turg  2015
# 1102   7658-1                                     Y-wing Fighter  2007
# 2363  40085-1                                     LEGO Valentine  2014
# ...       ...                                                ...   ...
# 477    3343-1  Star Wars #4 - Battle Droid Commander and 2 Ba...  2000
# 5107  40528-1                            LEGO Brand Retail Store  2022
# 1975  10226-1                                      Sopwith Camel  2012
# 4650  75939-1              Dr. Wu's Lab: Baby Dinosaurs Breakout  2020
# 3083  41572-1                                             Gobbol  2016
#
#                 Theme    Theme_Group                      Subtheme Category  \
# 3621            Duplo     Pre-school                           NaN   Normal
# 1291          Factory  Miscellaneous                   Custom Cars   Normal
# 2736           Mixels  Miscellaneous                      Series 5   Normal
# 1102        Star Wars       Licensed                    Episode IV   Normal
# 2363         Seasonal  Miscellaneous               Valentine's Day   Normal
# ...               ...            ...                           ...      ...
# 477         Star Wars       Licensed                  Minifig Pack   Normal
# 5107      Promotional  Miscellaneous  LEGO brand store opening set   Normal
# 1975  Advanced models   Model making                      Aircraft   Normal
# 4650   Jurassic World       Licensed         Legend of Isla Nublar   Normal
# 3083           Mixels  Miscellaneous                      Series 9   Normal
#
#       Packaging  Num_Instructions     Availability  Pieces  Minifigures  \
# 3621        Box                 2  {Not specified}    29.0          3.0
# 1291        Box                 0   LEGO exclusive   893.0          4.0
# 2736  Foil pack                 3           Retail    56.0          NaN
# 1102        Box                 1  {Not specified}   454.0          2.0
# 2363        Box                 1   LEGO exclusive   127.0          NaN
# ...         ...               ...              ...     ...          ...
# 477         Box                 0   LEGO exclusive    30.0          3.0
# 5107        Box                 2   LEGO exclusive   402.0          NaN
# 1975        Box                 4   LEGO exclusive   883.0          NaN
# 4650        Box                 2           Retail   164.0          2.0
# 3083  Foil pack                 3           Retail    62.0          NaN
#
#       Owned  Rating  USD_MSRP  Total_Quantity  Current_Price
# 3621    909     4.2     24.99               1        23.9900
# 1291    729     0.0     69.99               2       110.6153
# 2736   2828     3.8      4.99               1         8.0000
# 1102   7927     4.1     39.99               4        74.0594
# 2363   2171     3.9      9.99               2        15.0000
# ...     ...     ...       ...             ...            ...
# 477    1377     3.9       NaN               3        70.0000
# 5107    878     0.0       NaN               4        49.9900
# 1975   6600     4.5     99.99               7       180.0000
# 4650   4261     4.0     19.99               7        24.9700
# 3083   1906     4.0      4.99               1        14.8462
#
# [1088 rows x 17 columns]

# %% [markdown]
# ### Access the column lables of a Dataframe

# %%
df.columns
# Out:
# Index(['Set_ID', 'Name', 'Year', 'Theme', 'Theme_Group', 'Subtheme',
#        'Category', 'Packaging', 'Num_Instructions', 'Availability', 'Pieces',
#        'Minifigures', 'Owned', 'Rating', 'USD_MSRP', 'Total_Quantity',
#        'Current_Price'],
#       dtype='object')

# %% [markdown]
# ### Access the datatypes of each columns in a Dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1088 entries, 3621 to 3083
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Set_ID            1088 non-null   object
#  1   Name              1088 non-null   object
#  2   Year              1088 non-null   int64
#  3   Theme             1088 non-null   object
#  4   Theme_Group       1088 non-null   object
#  5   Subtheme          976 non-null    object
#  6   Category          1088 non-null   object
#  7   Packaging         1088 non-null   object
#  8   Num_Instructions  1088 non-null   int64
#  9   Availability      1088 non-null   object
#  10  Pieces            1083 non-null   float64
#  11  Minifigures       744 non-null    float64
#  12  Owned             1088 non-null   int64
#  13  Rating            1088 non-null   float64
#  14  USD_MSRP          706 non-null    float64
#  15  Total_Quantity    1088 non-null   int64
#  16  Current_Price     1088 non-null   float64
# dtypes: float64(5), int64(4), object(8)
# memory usage: 153.0+ KB

# %% [markdown]
# ### describe() method: descriptive statistics of a DataFrame's numerical columns.¶

# %%
df.describe()
# Out:
#               Year  Num_Instructions        Pieces  Minifigures         Owned  \
# count  1088.000000       1088.000000   1083.000000   744.000000   1088.000000
# mean   2012.249081          2.291360    309.779317     2.962366   3809.246324
# std       8.877138          2.235994    584.002804     2.588136   3668.944462
# min    1975.000000          0.000000      1.000000     1.000000     18.000000
# 25%    2008.000000          1.000000     50.000000     1.000000   1298.000000
# 50%    2015.000000          2.000000    129.000000     2.000000   2822.000000
# 75%    2019.000000          3.000000    330.000000     4.000000   5003.750000
# max    2023.000000         21.000000  10001.000000    24.000000  27799.000000
#
#             Rating    USD_MSRP  Total_Quantity  Current_Price
# count  1088.000000  706.000000     1088.000000    1088.000000
# mean      3.184926   42.940269       10.711397      90.326477
# std       1.509520   56.716462       41.654683     231.565915
# min       0.000000    2.490000        1.000000       1.990000
# 25%       3.400000    9.990000        1.000000      15.000000
# 50%       3.800000   24.990000        3.000000      34.645500
# 75%       4.000000   49.990000        8.000000      90.000000
# max       4.800000  629.990000     1063.000000    5000.000000

# %% [markdown]
# ### Length of the speech

# %%
# Specify the columns
columns_to_measure = ['Set_ID', 'Name', 'Year', 'Theme', 'Theme_Group', 'Subtheme',
       'Category', 'Packaging', 'Num_Instructions', 'Availability', 'Pieces',
       'Minifigures', 'Owned', 'Rating', 'USD_MSRP', 'Total_Quantity',
       'Current_Price']# Calculate the length of each column
column_lengths = {column: len(df[column]) for column in columns_to_measure}

# Display the lengths of the specified columns
for column, length in column_lengths.items():
    print(f"Length of {column}: {length}")
# Out:
# Length of Set_ID: 1088
# Length of Name: 1088
# Length of Year: 1088
# Length of Theme: 1088
# Length of Theme_Group: 1088
# Length of Subtheme: 1088
# Length of Category: 1088
# Length of Packaging: 1088
# Length of Num_Instructions: 1088
# Length of Availability: 1088
# Length of Pieces: 1088
# Length of Minifigures: 1088
# Length of Owned: 1088
# Length of Rating: 1088
# Length of USD_MSRP: 1088
# Length of Total_Quantity: 1088
# Length of Current_Price: 1088

# %% [markdown]
# ### Stats about text fields¶

# %%
df.describe(include='O')
# Out:
#          Set_ID     Name Theme Theme_Group Subtheme Category Packaging  \
# count      1088     1088  1088        1088      976     1088      1088
# unique     1088     1056   103          16      349        5        15
# top     10871-1  Snowman  City    Licensed   3 in 1   Normal       Box
# freq          1        4   119         307       43     1065       780
#
#        Availability
# count          1088
# unique           10
# top          Retail
# freq            671

# %% [markdown]
# ### Checking the missing data

# %%
df.isna().sum()
# Out:
# Set_ID                0
# Name                  0
# Year                  0
# Theme                 0
# Theme_Group           0
# Subtheme            112
# Category              0
# Packaging             0
# Num_Instructions      0
# Availability          0
# Pieces                5
# Minifigures         344
# Owned                 0
# Rating                0
# USD_MSRP            382
# Total_Quantity        0
# Current_Price         0
# dtype: int64

# %% [markdown]
# ### Filling the missing data

# %%
df['Subtheme'].fillna('unknown', inplace=True)
df['USD_MSRP'].fillna('unknown', inplace=True)
df['Pieces'].fillna('unknown', inplace=True)
df['Minifigures'].fillna('unknown', inplace=True)
df.isna().sum()
# Out:
# Set_ID              0
# Name                0
# Year                0
# Theme               0
# Theme_Group         0
# Subtheme            0
# Category            0
# Packaging           0
# Num_Instructions    0
# Availability        0
# Pieces              0
# Minifigures         0
# Owned               0
# Rating              0
# USD_MSRP            0
# Total_Quantity      0
# Current_Price       0
# dtype: int64

# %% [markdown]
# ### Uppercase or lowercase all text

# %%
df['Name'] = df['Name'].str.upper()
df['Theme'] = df['Theme'].str.upper()
df['Theme_Group'] = df['Theme_Group'].str.upper()
print(df)
# Out:
#        Set_ID                                               Name  Year  \
# 3621  10871-1                                            AIRPORT  2018
# 1291  10200-1                                  CUSTOM CAR GARAGE  2008
# 2736  41543-1                                               TURG  2015
# 1102   7658-1                                     Y-WING FIGHTER  2007
# 2363  40085-1                                     LEGO VALENTINE  2014
# ...       ...                                                ...   ...
# 477    3343-1  STAR WARS #4 - BATTLE DROID COMMANDER AND 2 BA...  2000
# 5107  40528-1                            LEGO BRAND RETAIL STORE  2022
# 1975  10226-1                                      SOPWITH CAMEL  2012
# 4650  75939-1              DR. WU'S LAB: BABY DINOSAURS BREAKOUT  2020
# 3083  41572-1                                             GOBBOL  2016
#
#                 Theme    Theme_Group                      Subtheme Category  \
# 3621            DUPLO     PRE-SCHOOL                      Subtheme   Normal
# 1291          FACTORY  MISCELLANEOUS                   Custom Cars   Normal
# 2736           MIXELS  MISCELLANEOUS                      Series 5   Normal
# 1102        STAR WARS       LICENSED                    Episode IV   Normal
# 2363         SEASONAL  MISCELLANEOUS               Valentine's Day   Normal
# ...               ...            ...                           ...      ...
# 477         STAR WARS       LICENSED                  Minifig Pack   Normal
# 5107      PROMOTIONAL  MISCELLANEOUS  LEGO brand store opening set   Normal
# 1975  ADVANCED MODELS   MODEL MAKING                      Aircraft   Normal
# 4650   JURASSIC WORLD       LICENSED         Legend of Isla Nublar   Normal
# 3083           MIXELS  MISCELLANEOUS                      Series 9   Normal
#
#       Packaging  Num_Instructions     Availability Pieces Minifigures  Owned  \
# 3621        Box                 2  {Not specified}   29.0         3.0    909
# 1291        Box                 0   LEGO exclusive  893.0         4.0    729
# 2736  Foil pack                 3           Retail   56.0     unknown   2828
# 1102        Box                 1  {Not specified}  454.0         2.0   7927
# 2363        Box                 1   LEGO exclusive  127.0     unknown   2171
# ...         ...               ...              ...    ...         ...    ...
# 477         Box                 0   LEGO exclusive   30.0         3.0   1377
# 5107        Box                 2   LEGO exclusive  402.0     unknown    878
# 1975        Box                 4   LEGO exclusive  883.0     unknown   6600
# 4650        Box                 2           Retail  164.0         2.0   4261
# 3083  Foil pack                 3           Retail   62.0     unknown   1906
#
#       Rating USD_MSRP  Total_Quantity  Current_Price
# 3621     4.2    24.99               1        23.9900
# 1291     0.0    69.99               2       110.6153
# 2736     3.8     4.99               1         8.0000
# 1102     4.1    39.99               4        74.0594
# 2363     3.9     9.99               2        15.0000
# ...      ...      ...             ...            ...
# 477      3.9  unknown               3        70.0000
# 5107     0.0  unknown               4        49.9900
# 1975     4.5    99.99               7       180.0000
# 4650     4.0    19.99               7        24.9700
# 3083     4.0     4.99               1        14.8462
#
# [1088 rows x 17 columns]

# %% [markdown]
# ### First of all let us evaluate the target and find out if our data is imbalanced or not

# %%
import seaborn as sns
import pandas as pd

# Define your data
data = {
    'snatch1': [1, 0, 1, 1, 0, 1, 0],
    'other_column': ['A', 'B', 'A', 'A', 'B', 'B', 'A']  # Example additional column
}

# Create DataFrame
df = pd.DataFrame(data)

# Define your palette colors
cols = ["#7056", "#136070"]

# Create a count plot for the 'snatch1' column
sns.countplot(x=df["snatch1"], palette=cols)
# Out:
# <Axes: xlabel='snatch1', ylabel='count'>

# %% [markdown]
# ### Charts

# %%
import matplotlib.pyplot as plt

# Hypothetical data for weight lifted for each exercise
exercises = ['Squats', 'Bench Press', 'Deadlifts']
weights_lifted = [225, 185, 315]  # Example weights lifted in pounds

# Create bar plot
plt.figure(figsize=(8, 6))
plt.bar(exercises, weights_lifted, color='skyblue')
plt.title('Amount of Weight Lifted for Different Exercises')
plt.xlabel('Exercise')
plt.ylabel('Weight Lifted (lbs)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
import seaborn as sns

file = "Lego Data.csv"
df = pd.read_csv(file, encoding='ISO-8859-1')  # Specify the correct encoding here

# Plot a count plot for the 'Theme' column (assuming 'age' is one of your columns)
plt.figure(figsize=(18,10))
sns.countplot(x='Theme', data=df)


# Plot a count plot for the 'Survived' column
sns.countplot(x='Theme_Group', data=df)

# Display the plot
plt.xlabel('Snatch')
plt.ylabel('Theme')
plt.title('Lego Themes')
plt.show()

# %% [markdown]
# ### Barplot`

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the dataset
file = "Lego Data.csv"
df = pd.read_csv(file, encoding='ISO-8859-1')

# Count the number of athletes from each country
category_counts = df['Category'].value_counts()

# Plotting
plt.figure(figsize=(5,5))
sns.barplot(x=category_counts.index, y=category_counts.values, palette='viridis')
plt.title('Number of categories')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
import pandas as pd

file = "Lego Data.csv"
df = pd.read_csv(file, encoding='ISO-8859-1')

print(df.columns)
# Out:
# Index(['ï»¿Set_ID', 'Name', 'Year', 'Theme', 'Theme_Group', 'Subtheme',
#        'Category', 'Packaging', 'Num_Instructions', 'Availability', 'Pieces',
#        'Minifigures', 'Owned', 'Rating', 'USD_MSRP', 'Total_Quantity',
#        'Current_Price'],
#       dtype='object')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns
numeric_data = df.select_dtypes(include=['number'])

# Correlation amongst numeric attributes
corrmat = numeric_data.corr()

# Define a color map for the heatmap
cmap = sns.diverging_palette(260, -10, s=50, l=75, n=6, as_cmap=True)

# Set the size of the heatmap
plt.subplots(figsize=(10, 8))

# Create the heatmap using seaborn
sns.heatmap(corrmat, cmap=cmap, annot=True, square=True)

# Show the plot
plt.show()

# %% [markdown]
# ### Display the length distribution of the 'Name' column

# %%
lengths = df["Name"].astype(str).str.len()

# Display the length distribution of the 'Name' column
lengths.value_counts()
# Out:
# Name
# 18    308
# 13    305
# 16    301
# 17    298
# 15    290
# 14    288
# 12    281
# 11    266
# 10    251
# 20    249
# 19    245
# 21    210
# 22    177
# 23    174
# 9     156
# 5     139
# 25    137
# 24    128
# 7     120
# 8     114
# 27    113
# 6     111
# 26    103
# 29     96
# 28     95
# 30     64
# 4      62
# 32     45
# 31     41
# 33     34
# 34     30
# 3      29
# 36     26
# 38     23
# 37     22
# 35     17
# 39     16
# 40     14
# 41     13
# 43      7
# 44      7
# 51      4
# 50      4
# 42      4
# 53      3
# 46      3
# 48      3
# 2       2
# 52      2
# 56      2
# 57      2
# 49      1
# 45      1
# 64      1
# 47      1
# 60      1
# 58      1
# 62      1
# 63      1
# Name: count, dtype: int64

# %% [markdown]
# ### Gender distribution by weightlifiting

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read the dataset
file = "Lego Data.csv"
df = pd.read_csv(file, encoding='ISO-8859-1')

# Create the distribution plot for gender
plt.figure(figsize=(18, 10))
sns.countplot(data=df, x='Availability')
plt.title('Legos Distribution')
plt.xlabel('Availability')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### A famous regex to pull out words

# %%
import pandas as pd

# Assuming 'athlete' is the column containing athlete names in your DataFrame
# Replace 'athlete' with the actual column name from your DataFrame
words = df['Name'].str.findall(r'\b\w+\b')

# Convert the resulting list of lists into a flat list of words
word_list = [word for sublist in words for word in sublist]

print(word_list)
# Out:
# ['Police', 'Patrol', 'Police', 'Launch', 'Coast', 'Guard', 'Station', 'Fire', 'Truck', 'Storage', 'Cloth', 'Digger', 'Bucket', 'Assembly', 'Train', 'Power', 'Pick', 'Up', 'Blocks', 'Tow', 'Truck', 'and', 'Car', 'Go', 'Kart', 'Road', 'Plates', 'Junction', 'Taxi', 'Auto', 'Service', 'Lighting', 'Brick', '4', '5V', 'Trees', 'and', 'Flowers', 'Highway', 'Repair', 'Exxon', 'Tow', 'Truck', 'Shell', 'Tanker', 'Wagon', 'Passenger', 'Coach', 'Railway', 'Station', '8', 'Straight', 'Rails', 'Grey', '4', '5V', 'Left', 'and', 'Right', 'Points', 'Manual', 'Grey', '4', '5V', 'Crossing', 'Grey', '4', '5V', 'Police', 'Patrol', 'Remote', 'Controlled', 'Decoupling', 'and', 'Signal', '12V', 'Car', 'Boat', 'Helicopter', 'Aircraft', 'Police', 'Car', 'Surface', 'Transport', 'Diesel', 'Heavy', 'Shunting', 'Locomotive', '4', 'Lighting', 'Standards', 'Electric', '12V', 'Technic', 'II', 'Powered', 'Machines', 'Set', 'Fire', 'Truck', 'Basic', 'Building', 'Set', '5', 'Basic', 'Building', 'Set', '7', 'Basic', 'Motor', 'Set', 'Basic', 'Building', 'Set', 'Basic', 'Building', 'Set', 'Jet', 'Airliner', 'Formula', '1', 'Racer', 'Rescue', 'I', 'Helicopter', 'Walking', 'Astro', 'Grappler', 'Solar', 'Power', 'Transporter', 'Crane', 'Wagon', 'Road', 'Crossing', 'Baseplate', 'Green', 'Santa', 'Claus', 'Lunar', 'Scout', 'Highway', 'Rig', 'Maiden', 's', 'Cart', 'Guarded', 'Inn', 'Black', 'Falcon', 's', 'Fortress', 'Road', 'Plates', 'Curved', 'Road', 'Plates', 'Straight', 'Road', 'Plates', 'Cross', 'Bulldozer', 'TV', 'Camera', 'Crew', 'Motocross', 'Racing', 'Space', 'Mini', 'Figures', 'Alien', 'Moon', 'Stalker', 'Container', 'Crane', 'Depot', 'Trial', 'Size', 'Offer', 'Basic', 'Set', '3', 'Basic', 'Set', '3', 'Replacement', 'Motor', '4', '5V', 'Light', 'and', 'Sound', '1', 'x', '4', 'Lighting', 'Brick', 'and', '4', 'Colour', 'Globes', 'Motor', '4', '5V', 'Pneumatic', 'Piston', 'Cylinder', '48', 'mm', 'Yellow', 'Emergency', 'Treatment', 'Center', 'Sport', 'Convertible', 'Turbo', 'Racer', 'Emergency', 'Repair', 'Truck', '4', 'Wheelin', 'Truck', 'Galaxy', 'Trekkor', 'Strata', 'Scooter', 'Orion', 'II', 'Hyperspace', 'Invader', 'Battrax', 'Renegade', 'Polaris', 'I', 'Space', 'Lab', 'Basic', 'Bricks', 'Victory', 'Racer', 'Town', 'Mini', 'Figures', 'Med', 'Star', 'Rescue', 'Plane', 'Victory', 'Lap', 'Raceway', 'Vacation', 'Camper', 'Strategic', 'Pursuer', 'Alienator', 'Snowman', 'Angel', 'Santa', 'Tuttle', 'the', 'Turtle', 'Lightning', 'Striker', 'Wind', 'Whirler', 'Turbo', 'Force', 'Swamp', 'Stinger', 'Sea', 'Skimmer', 'Battery', 'Box', '9V', 'Electric', 'System', 'Flashlight', 'Unit', '12V', 'Pneumatic', 'Pump', 'Cylinder', '48', 'mm', 'Pneumatic', 'Tubing', 'and', 'T', 'Junctions', 'Castle', 'Elements', 'Knight', 's', 'Challenge', 'Forestmen', 's', 'River', 'Fortress', 'Buried', 'Treasure', 'Pirate', 'Minifigures', 'Shipwreck', 'Island', 'Eldorado', 'Fortress', 'SP', 'Striker', 'Message', 'Decoder', 'Galactic', 'Peace', 'Keeper', 'Spy', 'Trak', '1', 'Space', 'Lock', 'Up', 'Isolation', 'Base', 'Basic', 'Building', 'Set', '7', 'Glory', 'Glider', 'Stunt', 'Chopper', 'Wave', 'Jumper', 'Track', 'Blaster', 'Speedboat', 'Rabbit', 'Basic', 'Building', 'Set', '5', 'Crusader', 's', 'Cart', 'Black', 'Monarch', 's', 'Ghost', 'Forestmen', 's', 'Crossing', 'Breezeway', 'Cafâ', 'Â', 'Mega', 'Core', 'Magnetizer', '9V', 'Motor', 'Set', 'Red', 'Race', 'Car', 'Number', '3', 'Snowman', 'Santa', 's', 'Elves', 'Firefighter', 'Straight', 'Rails', 'Curved', 'Rails', 'Manual', 'Points', 'with', 'Track', 'Blue', 'Hopper', 'Car', 'Transformer', 'and', 'Speed', 'Regulator', 'Metro', 'Station', 'Metroliner', 'Load', 'N', 'Haul', 'Railroad', 'Motor', '9V', 'Broadside', 's', 'Brig', 'Lagoon', 'Lock', 'Up', 'Jetport', 'Fire', 'Squad', 'Diesel', 'Dumper', 'Intercoastal', 'Seaport', 'Minifig', 'Pack', 'Aerial', 'Intruder', 'Mountain', 'Rambler', 'Lighting', 'Set', '9V', 'Galactic', 'Scout', 'Battle', 'Cove', 'Santa', 'and', 'Chimney', 'Large', 'Building', 'Plate', 'Pneumatic', 'Piston', 'Cylinder', '32', ' ...

# %%
import pandas as pd
import regex as re

def tokenize(text):
    return re.findall(r'[\w-]*[a-zA-Z][\w-]*', text)

file_path = "Lego Data.csv"

# Specify the encoding as 'ISO-8859-1' to avoid UnicodeDecodeError
df = pd.read_csv(file_path, encoding='ISO-8859-1')

# Replace 'athlete' with the actual name of the column containing the athlete names
df['tokenized_text'] = df['Name'].apply(lambda x: tokenize(str(x)))

# Display the DataFrame with the tokenized text
print(df[['Name', 'tokenized_text']].head())
# Out:
#                   Name           tokenized_text
# 0        Police Patrol         [Police, Patrol]
# 1        Police Launch         [Police, Launch]
# 2  Coast Guard Station  [Coast, Guard, Station]
# 3           Fire Truck            [Fire, Truck]
# 4        Storage Cloth         [Storage, Cloth]

# %% [markdown]
# ### Remove Stop words

# %%
import nltk
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'herself', 'some', 'after', 'be', 'such', 'this', 'isn', 'where', 'ain', 'a', 'again', 'couldn', "you're", "it's", 'shan', "shouldn't", 'of', 'at', 'down', 'yourselves', 'ours', 'from', 'themselves', 'him', 'out', "you've", 'now', 'own', 'will', 'between', 'hers', 'they', 'and', "couldn't", 'was', 'just', 'are', 'no', 'whom', 'needn', 'me', 'how', 'further', "mustn't", 'but', 'is', "weren't", 'myself', 'each', 'those', 'ourselves', "mightn't", "you'll", "don't", 'you', "hadn't", 'nor', 'below', 'during', 'when', 'll', 'before', 'what', 'y', 'shouldn', 'very', 'were', 'as', 'into', 'for', 'then', 'few', 'that', 'she', "that'll", "won't", 'had', 'any', 'hadn', "didn't", 'should', 'it', 'an', 'or', "aren't", 'hasn', 'above', 'has', 'most', 'only', 'yourself', 'off', 'do', 'my', 'more', 've', "she's", 'here', 'while', 'o', 'can', 'both', 'mustn', 'our', 'which', "needn't", 'to', 't', "doesn't", 'wasn', 'all', 'by', 'doesn', 'i', 're', 'd', 'once', 'against', 'ma', 'why', "wouldn't", 'the', 'weren', 'have', 'didn', "haven't", 'doing', 'so', 'did', 'there', 'm', 'aren', 'if', 'who', "hasn't", 'himself', 'your', 'am', 'in', 'until', 'these', 'been', "shan't", 'on', 'too', 'her', 'with', "you'd", "wasn't", 'we', 'he', 's', 'wouldn', 'being', 'itself', 'theirs', 'through', 'his', 'its', 'under', 'yours', 'about', 'because', 'than', 'over', 'same', 'up', 'their', 'don', "isn't", 'mightn', 'them', 'other', 'won', 'not', 'does', "should've", 'haven', 'having'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dharm\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Function to remove stop words

# %%
import pandas as pd
import nltk

# Download English stopwords
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))

# Define the remove_stop function
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]

# Read the CSV file into a DataFrame with the specified encoding
file_path = "Lego Data.csv"
df = pd.read_csv(file_path, encoding='ISO-8859-1')

# Apply the remove_stop function to the 'athlete' column and create a new column 'cleantokens'
df['cleantokens'] = df['Name'].apply(lambda x: remove_stop(str(x).split()))

# Display the DataFrame with the cleaned tokens
print(df[['Name', 'cleantokens']].tail())
# Out:
#                                   Name                        cleantokens
# 5437         Temple of the Golden Idol             [Temple, Golden, Idol]
# 5438           Monkie Kid's Combi Mech       [Monkie, Kid's, Combi, Mech]
# 5439        Master Wu vs. Ghost Archer   [Master, Wu, vs., Ghost, Archer]
# 5440  Cave Explorer, Creeper and Slime  [Cave, Explorer,, Creeper, Slime]
# 5441                     Miles Morales                   [Miles, Morales]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dharm\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### pipeline

# %%
import pandas as pd
import nltk
from sklearn.pipeline import Pipeline
from sklearn.base import TransformerMixin
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download English stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Define a custom transformer for tokenization
class Tokenizer(TransformerMixin):
    def transform(self, X, **transform_params):
        return [word_tokenize(text) for text in X]

    def fit(self, X, y=None, **fit_params):
        return self

# Define a custom transformer for removing stopwords
class StopWordRemover(TransformerMixin):
    def transform(self, X, **transform_params):
        return [[word for word in text if word.lower() not in stop_words] for text in X]

    def fit(self, X, y=None, **fit_params):
        return self

# Read the CSV file into a DataFrame
file_path = "Lego Data.csv"
df = pd.read_csv(file_path, encoding='ISO-8859-1')

# Define the pipeline
pipeline = Pipeline([
    ('tokenize', Tokenizer()),
    ('remove_stopwords', StopWordRemover())
])

# Apply the pipeline to the 'athlete' column
cleaned_text = pipeline.fit_transform(df['Name'])

# Display the cleaned text
print(cleaned_text)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dharm\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [['Police', 'Patrol'], ['Police', 'Launch'], ['Coast', 'Guard', 'Station'], ['Fire', 'Truck'], ['Storage', 'Cloth'], ['Digger', 'Bucket', 'Assembly'], ['Train', 'Power', 'Pick-Up', 'Blocks'], ['Tow', 'Truck', 'Car'], ['Go-Kart'], ['Road', 'Plates', ',', 'Junction'], ['Taxi'], ['Auto', 'Service'], ['Lighting', 'Brick', ',', '4.5V'], ['Trees', 'Flowers'], ['Highway', 'Repair'], ['Exxon', 'Tow', 'Truck'], ['Shell', 'Tanker', 'Wagon'], ['Passenger', 'Coach'], ['Railway', 'Station'], ['8', 'Straight', 'Rails', 'Grey', '4.5V'], ['Left', 'Right', 'Points', 'Manual', 'Grey', '4.5V'], ['Crossing', ',', 'Grey', '4.5V'], ['Police', 'Patrol'], ['Remote', 'Controlled', 'Decoupling', 'Signal', '12V'], ['Car'], ['Boat'], ['Helicopter'], ['Aircraft'], ['Police', 'Car'], ['Surface', 'Transport'], ['Diesel', 'Heavy', 'Shunting', 'Locomotive'], ['4', 'Lighting', 'Standards', 'Electric', '12V'], ['Technic', 'II', 'Powered', 'Machines', 'Set'], ['Fire', 'Truck'], ['Basic', 'Building', 'Set', ',', '5+'], ['Basic', 'Building', 'Set', ',', '7+'], ['Basic', 'Motor', 'Set'], ['Basic', 'Building', 'Set'], ['Basic', 'Building', 'Set'], ['Jet', 'Airliner'], ['Formula', '1', 'Racer'], ['Rescue-I', 'Helicopter'], ['Walking', 'Astro', 'Grappler'], ['Solar', 'Power', 'Transporter'], ['Crane', 'Wagon'], ['Road', 'Crossing'], ['Baseplate', ',', 'Green'], ['Santa', 'Claus'], ['Lunar', 'Scout'], ['Highway', 'Rig'], ['Maiden', "'s", 'Cart'], ['Guarded', 'Inn'], ['Black', 'Falcon', "'s", 'Fortress'], ['Road', 'Plates', ',', 'Curved'], ['Road', 'Plates', ',', 'Straight'], ['Road', 'Plates', ',', 'Cross'], ['Bulldozer'], ['TV', 'Camera', 'Crew'], ['Motocross', 'Racing'], ['Space', 'Mini-Figures'], ['Alien', 'Moon', 'Stalker'], ['Container', 'Crane', 'Depot'], ['Trial', 'Size', 'Offer'], ['Basic', 'Set', '3+'], ['Basic', 'Set', '3+'], ['Replacement', 'Motor', '4.5V'], ['Light', 'Sound', '1', 'x', '4', 'Lighting', 'Brick', '4', 'Colour', 'Globes'], ['Motor', '4.5V'], ['Pneumatic', 'Piston', 'Cylinder', '48', 'mm', 'Yellow'], ['Emergency', 'Treatment', 'Center'], ['Sport', 'Convertible'], ['Turbo', 'Racer'], ['Emergency', 'Repair', 'Truck'], ['4-Wheelin', "'", 'Truck'], ['Galaxy', 'Trekkor'], ['Strata', 'Scooter'], ['Orion', 'II', 'Hyperspace'], ['Invader'], ['Battrax'], ['Renegade'], ['Polaris', 'Space', 'Lab'], ['Basic', 'Bricks'], ['Victory', 'Racer'], ['Town', 'Mini-Figures'], ['Med-Star', 'Rescue', 'Plane'], ['Victory', 'Lap', 'Raceway'], ['Vacation', 'Camper'], ['Strategic', 'Pursuer'], ['Alienator'], ['Snowman'], ['Angel'], ['Santa'], ['Tuttle', 'Turtle'], ['Lightning', 'Striker'], ['Wind', 'Whirler'], ['Turbo', 'Force'], ['Swamp', 'Stinger'], ['Sea', 'Skimmer'], ['Battery', 'Box', '9V', 'Electric', 'System'], ['Flashlight', 'Unit', '12V'], ['Pneumatic', 'Pump', 'Cylinder', '48', 'mm'], ['Pneumatic', 'Tubing', 'T-Junctions'], ['Castle', 'Elements'], ['Knight', "'s", 'Challenge'], ['Forestmen', "'s", 'River', 'Fortress'], ['Buried', 'Treasure'], ['Pirate', 'Minifigures'], ['Shipwreck', 'Island'], ['Eldorado', 'Fortress'], ['SP-Striker'], ['Message', 'Decoder'], ['Galactic', 'Peace', 'Keeper'], ['Spy', 'Trak', '1'], ['Space', 'Lock-Up', 'Isolation', 'Base'], ['Basic', 'Building', 'Set', ',', '7+'], ['Glory', 'Glider'], ['Stunt', 'Chopper'], ['Wave', 'Jumper'], ['Track', 'Blaster'], ['Speedboat'], ['Rabbit'], ['Basic', 'Building', 'Set', ',', '5+'], ['Crusader', "'s", 'Cart'], ['Black', 'Monarch', "'s", 'Ghost'], ['Forestmen', "'s", 'Crossing'], ['Breezeway', 'Cafâ\x88\x9aÂ©'], ['Mega', 'Core', 'Magnetizer'], ['9V', 'Motor', 'Set'], ['Red', 'Race', 'Car', 'Number', '3'], ['Snowman'], ['Santa', "'s", 'Elves'], ['Firefighter'], ['Straight', 'Rails'], ['Curved', 'Rails'], ['Manual', 'Points', 'Track'], ['Blue', 'Hopper', 'Car'], ['Transformer', 'Speed', 'Regulator'], ['Metro', 'Station'], ['Metroliner'], ['Load', 'N', "'", 'Haul', 'Railroad'], ['Motor', '9V'], ['Broadside', "'s", 'Brig'], ['Lagoon', 'Lock-Up'], ['Jetport', 'Fire', 'Squad'], ['Diesel', 'Dumper'], ['Inte ...

# %% [markdown]
# ### Run the pipeline

# %%
import pandas as pd
import nltk
from sklearn.pipeline import Pipeline
from sklearn.base import TransformerMixin
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download English stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Define a custom transformer for tokenization
class Tokenizer(TransformerMixin):
    def transform(self, X, **transform_params):
        return [word_tokenize(text) for text in X]

    def fit(self, X, y=None, **fit_params):
        return self

# Define a custom transformer for removing stopwords
class StopWordRemover(TransformerMixin):
    def transform(self, X, **transform_params):
        return [[word for word in text if word.lower() not in stop_words] for text in X]

    def fit(self, X, y=None, **fit_params):
        return self

# Read the CSV file into a DataFrame
file_path = "Lego Data.csv"
df = pd.read_csv(file_path, encoding='ISO-8859-1')

# Define the pipeline
pipeline = Pipeline([
    ('tokenize', Tokenizer()),
    ('remove_stopwords', StopWordRemover())
])

# Apply the pipeline to the 'athlete' column
cleaned_text = pipeline.fit_transform(df['Name'])

# Display the cleaned text
print(cleaned_text)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dharm\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [['Police', 'Patrol'], ['Police', 'Launch'], ['Coast', 'Guard', 'Station'], ['Fire', 'Truck'], ['Storage', 'Cloth'], ['Digger', 'Bucket', 'Assembly'], ['Train', 'Power', 'Pick-Up', 'Blocks'], ['Tow', 'Truck', 'Car'], ['Go-Kart'], ['Road', 'Plates', ',', 'Junction'], ['Taxi'], ['Auto', 'Service'], ['Lighting', 'Brick', ',', '4.5V'], ['Trees', 'Flowers'], ['Highway', 'Repair'], ['Exxon', 'Tow', 'Truck'], ['Shell', 'Tanker', 'Wagon'], ['Passenger', 'Coach'], ['Railway', 'Station'], ['8', 'Straight', 'Rails', 'Grey', '4.5V'], ['Left', 'Right', 'Points', 'Manual', 'Grey', '4.5V'], ['Crossing', ',', 'Grey', '4.5V'], ['Police', 'Patrol'], ['Remote', 'Controlled', 'Decoupling', 'Signal', '12V'], ['Car'], ['Boat'], ['Helicopter'], ['Aircraft'], ['Police', 'Car'], ['Surface', 'Transport'], ['Diesel', 'Heavy', 'Shunting', 'Locomotive'], ['4', 'Lighting', 'Standards', 'Electric', '12V'], ['Technic', 'II', 'Powered', 'Machines', 'Set'], ['Fire', 'Truck'], ['Basic', 'Building', 'Set', ',', '5+'], ['Basic', 'Building', 'Set', ',', '7+'], ['Basic', 'Motor', 'Set'], ['Basic', 'Building', 'Set'], ['Basic', 'Building', 'Set'], ['Jet', 'Airliner'], ['Formula', '1', 'Racer'], ['Rescue-I', 'Helicopter'], ['Walking', 'Astro', 'Grappler'], ['Solar', 'Power', 'Transporter'], ['Crane', 'Wagon'], ['Road', 'Crossing'], ['Baseplate', ',', 'Green'], ['Santa', 'Claus'], ['Lunar', 'Scout'], ['Highway', 'Rig'], ['Maiden', "'s", 'Cart'], ['Guarded', 'Inn'], ['Black', 'Falcon', "'s", 'Fortress'], ['Road', 'Plates', ',', 'Curved'], ['Road', 'Plates', ',', 'Straight'], ['Road', 'Plates', ',', 'Cross'], ['Bulldozer'], ['TV', 'Camera', 'Crew'], ['Motocross', 'Racing'], ['Space', 'Mini-Figures'], ['Alien', 'Moon', 'Stalker'], ['Container', 'Crane', 'Depot'], ['Trial', 'Size', 'Offer'], ['Basic', 'Set', '3+'], ['Basic', 'Set', '3+'], ['Replacement', 'Motor', '4.5V'], ['Light', 'Sound', '1', 'x', '4', 'Lighting', 'Brick', '4', 'Colour', 'Globes'], ['Motor', '4.5V'], ['Pneumatic', 'Piston', 'Cylinder', '48', 'mm', 'Yellow'], ['Emergency', 'Treatment', 'Center'], ['Sport', 'Convertible'], ['Turbo', 'Racer'], ['Emergency', 'Repair', 'Truck'], ['4-Wheelin', "'", 'Truck'], ['Galaxy', 'Trekkor'], ['Strata', 'Scooter'], ['Orion', 'II', 'Hyperspace'], ['Invader'], ['Battrax'], ['Renegade'], ['Polaris', 'Space', 'Lab'], ['Basic', 'Bricks'], ['Victory', 'Racer'], ['Town', 'Mini-Figures'], ['Med-Star', 'Rescue', 'Plane'], ['Victory', 'Lap', 'Raceway'], ['Vacation', 'Camper'], ['Strategic', 'Pursuer'], ['Alienator'], ['Snowman'], ['Angel'], ['Santa'], ['Tuttle', 'Turtle'], ['Lightning', 'Striker'], ['Wind', 'Whirler'], ['Turbo', 'Force'], ['Swamp', 'Stinger'], ['Sea', 'Skimmer'], ['Battery', 'Box', '9V', 'Electric', 'System'], ['Flashlight', 'Unit', '12V'], ['Pneumatic', 'Pump', 'Cylinder', '48', 'mm'], ['Pneumatic', 'Tubing', 'T-Junctions'], ['Castle', 'Elements'], ['Knight', "'s", 'Challenge'], ['Forestmen', "'s", 'River', 'Fortress'], ['Buried', 'Treasure'], ['Pirate', 'Minifigures'], ['Shipwreck', 'Island'], ['Eldorado', 'Fortress'], ['SP-Striker'], ['Message', 'Decoder'], ['Galactic', 'Peace', 'Keeper'], ['Spy', 'Trak', '1'], ['Space', 'Lock-Up', 'Isolation', 'Base'], ['Basic', 'Building', 'Set', ',', '7+'], ['Glory', 'Glider'], ['Stunt', 'Chopper'], ['Wave', 'Jumper'], ['Track', 'Blaster'], ['Speedboat'], ['Rabbit'], ['Basic', 'Building', 'Set', ',', '5+'], ['Crusader', "'s", 'Cart'], ['Black', 'Monarch', "'s", 'Ghost'], ['Forestmen', "'s", 'Crossing'], ['Breezeway', 'Cafâ\x88\x9aÂ©'], ['Mega', 'Core', 'Magnetizer'], ['9V', 'Motor', 'Set'], ['Red', 'Race', 'Car', 'Number', '3'], ['Snowman'], ['Santa', "'s", 'Elves'], ['Firefighter'], ['Straight', 'Rails'], ['Curved', 'Rails'], ['Manual', 'Points', 'Track'], ['Blue', 'Hopper', 'Car'], ['Transformer', 'Speed', 'Regulator'], ['Metro', 'Station'], ['Metroliner'], ['Load', 'N', "'", 'Haul', 'Railroad'], ['Motor', '9V'], ['Broadside', "'s", 'Brig'], ['Lagoon', 'Lock-Up'], ['Jetport', 'Fire', 'Squad'], ['Diesel', 'Dumper'], ['Inte ...

# %% [markdown]
# ### Word frequencyAnalysis

# %%
from collections import Counter

tokens = tokenize("i love movies but movies are hard to make.")

testcount= Counter(tokens)
print(testcount)
# Out:
# Counter({'movies': 2, 'i': 1, 'love': 1, 'but': 1, 'are': 1, 'hard': 1, 'to': 1, 'make': 1})

# %% [markdown]
# ### Count

# %%
counter = Counter()
df['Name'].map(counter.update)
print(counter.most_common(5))
# Out:
# [(' ', 9570), ('e', 8836), ('a', 7003), ('r', 6812), ('i', 5240)]

# %% [markdown]
# ### Word Frequency

# %%
freq_df = pd.DataFrame.from_dict(counter,orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#        freq
# token
#        9570
# e      8836
# a      7003
# r      6812
# i      5240
# t      5122
# o      5088
# n      4583
# l      3425
# s      3413

# %% [markdown]
# ## Word Cloud

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
file_path = "Lego Data.csv"
# Read the CSV file into a DataFrame with a different encoding
df = pd.read_csv(file_path, encoding='ISO-8859-1')


# Concatenate text values from all relevant columns
text = ' '.join(df.astype(str).values.flatten())

# Define stopwords to exclude common words
stopwords = ["the", "and", "of", "in", "to", "a", "is", "it"]

# Create WordCloud with adjusted parameters
plt.figure(figsize=(14, 7))
wc = WordCloud(max_words=100, stopwords=stopwords, background_color='white',
               contour_width=0, contour_color='black', colormap='viridis')
wc.generate(text)

# Display the WordCloud
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## word cloud in circular shape

# %%
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import pandas as pd

# Concatenate text values from all relevant columns
text = ' '.join(df.astype(str).values.flatten())

# Circle mask
x, y = np.ogrid[:300, :300]
mask = (x - 150) ** 2 + (y - 150) ** 2 > 130 ** 2
mask = 255 * mask.astype(int)

# Create WordCloud with a circle mask
wc = WordCloud(background_color="white", repeat=True, mask=mask)
wc.generate(text)

plt.figure(figsize=(8, 8))
plt.axis("off")
plt.imshow(wc, interpolation="bilinear")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from PIL import Image
from io import BytesIO
import requests
import pandas as pd

file_path = "Lego Data.csv"
# Read the CSV file into a DataFrame with a different encoding
df = pd.read_csv(file_path, encoding='ISO-8859-1')

# Concatenate text values from all relevant columns
text = ' '.join(df.astype(str).values.flatten())

# From URL
response = requests.get("https://raw.githubusercontent.com/R-CoderDotCom/samples/main/wordcloud-mask.jpg")
mask = np.array(Image.open(BytesIO(response.content)))


wc = WordCloud(background_color="white", repeat=True, mask=mask)
wc.generate(text)

plt.figure(figsize=(8, 8))
plt.axis("off")
plt.imshow(wc, interpolation="bilinear")

plt.show()

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt


# Concatenate text values from all relevant columns
text = ' '.join(df.astype(str).values.flatten())

stopwords = ["the", "and", "of", "in", "to", "a", "is", "it"]

# Create WordCloud
plt.figure(figsize=(14, 7))
wc = WordCloud(max_words=100, stopwords=stopwords)
wc.generate(text)

# Display WordCloud
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud, ImageColorGenerator
from PIL import Image
from io import BytesIO
import requests
import pandas as pd

file_path = "Lego Data.csv"
# Read the CSV file into a DataFrame with a different encoding
df = pd.read_csv(file_path, encoding='ISO-8859-1')

# Concatenate text values from all relevant columns
text = ' '.join(df.astype(str).values.flatten())

# From URL
response = requests.get("http://clipart-library.com/images/pi58gAqbT.png")
mask = np.array(Image.open(BytesIO(response.content)))

# Colors
image_colors = ImageColorGenerator(mask)

wc = WordCloud(background_color="white", repeat=True, mask=mask)
wc.generate(text)

plt.figure(figsize=(8, 8))
plt.axis("off")
plt.imshow(wc.recolor(color_func=image_colors), interpolation="bilinear")

plt.show()

# %% [markdown]
# # Conclusion:

# %% [markdown]
# ### The conclusion is based on the insights gained from the visualizations, class distribution, gender distribution, bodyweight variation, various themes in the dataset and word cloud analysis.
